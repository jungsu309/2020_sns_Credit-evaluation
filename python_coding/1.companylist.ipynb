# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pymysql
import time
import datetime
import demoji
# 이모지 제거
demoji.download_codes()
###
def loginUrl(user_id, user_pw):
    try:
        url = "https://www.instagram.com/"
        driver = webdriver.Chrome("./chromedriver.exe")
        driver.get(url)
        time.sleep(2)
        driver.find_element_by_name("username").send_keys(user_id)
        driver.find_element_by_name("password").send_keys(user_pw)
        driver.find_element_by_xpath("//*[@id=\"loginForm\"]/div/div[3]/button").submit()
        time.sleep(3)
        driver.find_element_by_xpath("//*[@id=\"react-root\"]/section/main/div/div/div/div/button").click()
        time.sleep(3)
        driver.find_element_by_xpath("/html/body/div[4]/div/div/div/div[3]/button[2]").click()
        insta_search(driver, search)
    except:
        print("잘못된 아이디 또는 비밀번호입니다.")
###
def insta_search(driver, search):
    url_tmp = driver.current_url
    url = "https://www.instagram.com/explore/tags/{search}/?hl=ko".format(search=search) # 검색어로 찾기
    driver.get(url)
    time.sleep(2)
    insta_postList(driver)
###
def insta_postList(driver):
    url = driver.current_url
    insta_post_Urls_List = []
    driver.get(url)
    time.sleep(2)
    # 일정 시간동안 스크롤
    start = datetime.datetime.now()
    end = start + datetime.timedelta(seconds = 100)
    time.sleep(2)
    while True :
        insta_post_Urls = driver.find_elements_by_css_selector(".Nnq7C.weEfm .v1Nh3.kIKUG._bz0w a")
        for urlList in insta_post_Urls:
            insta_post_Urls_List.append(urlList.get_attribute("href"))
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(2)
        if datetime.datetime.now() > end:
            break
    insta_post_Urls_List = list(set(insta_post_Urls_List))
    print(len(insta_post_Urls_List))
    insta_accounts(driver,insta_post_Urls_List)
###

def insta_accounts(driver,insta_post_Urls_List):
    company=[]
    for urlList in insta_post_Urls_List:
        driver.get(urlList)
        time.sleep(1)
        try:
            driver.find_element_by_xpath('//*[@id="react-root"]/section/main/div/div[1]/article/header/div[2]/div[1]/div[1]/span/a').click()
            time.sleep(3)
            # 팔로워 수 출력
            userIDList = driver.find_elements_by_css_selector("._7UhW9.fKFbl.yUEEX.KV-D4.fDxYl")
            userID = userIDList[0].text # 아이디
            userInfoList = driver.find_elements_by_css_selector(".g47SY")
            userFollower = userInfoList[1] # 팔로워 수
            userFollowerReal = userFollower.get_attribute('title')
            if userFollower.text.find('백') == -1 and userFollower.text.find('천') == -1 and userFollower.text.find('만') == -1:
                userFollower = userFollower.text
            else:
                userFollower = userFollowerReal
            time.sleep(1)    
            print("\n")
            print("- 인스타그램 아이디 : " + userID)
            print("- 팔로워 수 : " + userFollower)
            print("\n")
            # 소개글
            intro = ""
            try:
                userInfoList = driver.find_elements_by_css_selector(".-vDIg span")
                intro = userInfoList[0].text
                intro = demoji.replace(intro," ")
                print(intro)
            except:
                continue
            # 인증 여부
            checks = ""
            checkList = driver.find_elements_by_css_selector(".Igw0E.IwRSH.eGOV_._4EzTm.soMvl")
            for check in checkList:
                checks = checks + check.text
            #팔로워수 제한
            userFollower = userFollower.replace(',', '')
            if checks.find('인증됨') == -1 and int(userFollower) <= 100000:
                for word in ['문의', '이벤트', '주문', '공구', '협찬', '판매', '마켓', '블로그', '링크', '세일', '할인', '카톡',
                            '카카오톡', '구매', '구입', '다이렉트', '택배', '배송', '제품', '상품', '스토어', '상점', '입금',
                            '플랫폼', 'DM', '디엠', '가격','오픈', 'kakaotalk', 'shop', '쇼핑몰', '샵','open']:
                    if intro.find(word) != -1:
                        company.append(userID)
                        break
        except:
            continue
    add_company(company)
###
def add_company(company):
    # 중복 제거
    f = open("C:/Users/정수/8%_project_python__int/8percent_company.txt", 'r')
    lines = f.readlines()
    companyList = company + lines
    companySet = set(companyList)
    f.close()
    # 메모장에 저장
    f = open("C:/Users/정수/8%_project_python__int/8percent_company.txt", 'w')
    for account in companySet:
        data = account + "\n"
        f.write(data)
    f.close()
###
#서안: '마켓', '쇼핑몰', '패션', '이벤트', '블로그마켓', '화장품'
#동두:  '주문제작', '스토어팜', '구제', '데일리룩', '자체제작', '여성의류'
#두유:  '아이폰케이스', '옷가게', '목걸이', '팔찌', '코디', '데일리코디'
#시엔: '베이킹', '맛집', '카페', '핸드메이드', '광고'

hashtagList = ['주문제작', '스토어팜', '구제', '데일리룩', '자체제작', '여성의류']
for hashtag in hashtagList:
    user_id = "jjungsu_drawing"
    user_pw = "jsjs532525!!"
    search = hashtag
    loginUrl(user_id, user_pw)
# Out:
# Downloading emoji data ...
# ... OK (Got response in 0.51 seconds)
# Writing emoji data to C:\Users\정수\.demoji\codes.json ...
# ... OK
# 528
#
#
# - 인스타그램 아이디 : arashi8307
# - 팔로워 수 : 164
#
#
#   +   =    ...
# 인형과 장난감 수집을 사랑하는
# 따님과 두아드님 , 두분의 냐옹님 모시는 집사
#
#
# - 인스타그램 아이디 : dw.bolt
# - 팔로워 수 : 97
#
#
# 자동차부품, 조선, 건축분야 볼트 전문 생산 업체입니다.
# 고객만족을 위해 최선을 다하겠습니다.
#
#
# - 인스타그램 아이디 : delpino_hands
# - 팔로워 수 : 340
#
#
# 핸드메이드 내츄럴 짙은 감성
# 매일매일 손에 잡히는
# 핸드메이드 패브릭
# 델피노핸즈
#
#
# - 인스타그램 아이디 : the_treetree
# - 팔로워 수 : 136
#
#
# 홈인테리어 가구/리빙 소품샵
#
#
# - 인스타그램 아이디 : blessgarden13
# - 팔로워 수 : 999
#
#
# 당신의 식탁이 아름다워지는 곳
# 그릇 주문제작/ 그릇판매
#
#
# - 인스타그램 아이디 : us_ricecake
# - 팔로워 수 : 21
#
#
# 주문시 픽업만 가능합니다(압구정동)
#   주문 문의
# 1. 010.4151.4548 으로 문자주시거나
# 2.   클릭하시면 채팅창으로 연결됩니다~
#
#
# - 인스타그램 아이디 : dyear._
# - 팔로워 수 : 100
#
#
# 물감 텍스쳐를 좋아하는
# 아크릴 물감으로 직접 그린 #그립톡 & #에어팟케이스
# ______________________
# 주문/문의 dm
#
#
# - 인스타그램 아이디 : flower_eum
# - 팔로워 수 : 398
#
#
# 경상북도 경산시 중방로57(중방동)
# 문의 : 010-2331-2021
# #경산꽃집 #중방동꽃집 #경산꽃배달
# 월~금: 9시-19시, 토:12시-18시, 일•공휴일은 휴무입니다
# 전화예약주문 ️ 경산배달 ️ 주문예약 ️
#
#
# - 인스타그램 아이디 : karen__factory
# - 팔로워 수 : 198
#
#
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# 1:1 핸드메이드 주얼리 공방
# 전 제품 귀금속을 이용하여 직접 핸드메이드로 수공합니다.
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#   문의는 하단 링크를 클릭해주세요
#
#
# - 인스타그램 아이디 : anjelajihee
# - 팔로워 수 : 365
#
#
# #압화작가 #압화강사 #압화 #꽃 #라리네집 #프레스플라워
#
#
# - 인스타그램 아이디 : damso21
# - 팔로워 수 : 1,121
#
#
# 완제 주문 제작은 DM주세요.
# 담소공방 스마트 스토어
#
#
# - 인스타그램 아이디 : shop_poett
# - 팔로워 수 : 12,605
#
#
# • ɢɪᴀ ᴄᴏʟᴏᴜʀᴇᴅ sᴛᴏɴᴇs ɢᴇᴍᴏʟᴏɢɪsᴛ
# • ᴊᴇᴡᴇʟʟᴇʀʏ ᴅᴇsɪɢɴᴇʀ
# ✤
#
#
# - 인스타그램 아이디 : j_woodlab
# - 팔로워 수 : 193
#
#
# Crafted by Jason Kang(@kangjeongwoong)
# 우리 몸에 편안함을 주는 디자인 추구♡&♡
# - #Woodwork
# - #Woodcrafts
# - #목공예 #우드카빙 #핸드메이드
# - #주방소품 #보석함 #시계케이스
# - DM문의 환영♡
#
#
# - 인스타그램 아이디 : kimsangmin_pottery
# - 팔로워 수 : 1,828
#
#
# 작업실&쇼룸 / 클래스/작품판매
# (DM문의) 01075504118
# @do_gong_ceramics
# 부산 수영구 과정로 42번길 22-1
#
#
# - 인스타그램 아이디 : hemming_ceramics
# - 팔로워 수 : 249
#
#
# hemming ceramic studio
# ⠀
# #정규클래스 #원데이클래스 #주문제작 가능합니다
# ⠀
#  .DM 문의
#  .02 701 1313
#  .카톡 플러스친구 @혜밍공방
# 서울시 종로구 평창11길 17 (평창동 세븐일레븐 3층)
#
#
# - 인스타그램 아이디 : cholssak_label
# - 팔로워 수 : 1
#
#
# #촐싹라벨
# - 라벨스티커 커미션 받습니다
# - 문의는 DM 부탁드려요
#
#
# - 인스타그램 아이디 : jiscakeboutique
# - 팔로워 수 : 549
#
#
# •Professor@LBCC
# •Pastry Chef@Ritz Carlton,Fourseasons, Roosevelt Hotel
# *Customized Cakes,Cupcakes in OC, LA
# *Licensed *Insured *Business Permit
#
#
# - 인스타그램 아이디 : nine.sports
# - 팔로워 수 : 1,988
#
#
# 서울시 중구 퇴계로 350 1,2층 ️
# 카카오톡 플러스 친구에서 나인스포츠를 검색 후 대화를 걸어주시면 빠른상담 해드리겠습니다.감사합니다.
#
#
# - 인스타그램 아이디 : som_x._.x
# - 팔로워 수 : 367
#
#
# H̊̈Å̈N̊̈D̊̈M̊̈Å̈D̊̈E̊̈
# 작업기록공간
# ෆ ෆ ෆ ෆ ෆ ෆ ෆ
#   페브릭 제품
# ʕっ•ᴥ•ʔっ
#
#
# - 인스타그램 아이디 : hvmiypj966153
# - 팔로워 수 : 13
#
#
#  강원출장업소 서울출장업소 경북출장업소
#  유흥업소 조건만남 애인대행
#  출장만남 출장안마 출장업소
#  출장샵후기 안마후기 마사지후기
#
#
# - 인스타그램 아이디 : ohio._.official
# - 팔로워 수 : 366
#
#
# 대구 수성구 목공방
#   카카오톡아이디 ohio2020
#   대구 수성구 범안로 3길 31 (범물동 1339-8)
#   원목가구 / 합판가구 / 원데이클래스
#
#
# - 인스타그램 아이디 : we_cherish__
# - 팔로워 수 : 164
#
#
# 문의사항 : 카카오톡 체널 위체리쉬
# Cherish : 소중히여기다 , 아끼다 라는 의미를 가진단어입니다
#  구매링크클릭
#
#
# - 인스타그램 아이디 : cafe_oneul.haru
# - 팔로워 수 : 303
#
#
# 부평구청역, 굴포천역
# 부평구 주부토로 151번길 31
# 공방 그리고 카페
# ( 프랑스자수 수업, 뜨개상품 판매, 공간대여 문의 DM )
# @oneulharu_yoon @euna_embroidery
#
#
# - 인스타그램 아이디 : nuricomm815
# - 팔로워 수 : 18
#
#
#
#
# - 인스타그램 아이디 : flaground_official
# - 팔로워 수 : 24
#
#
# There is no miracle, but keep dreaming.
#
#
# - 인스타그램 아이디 : yunri.i
# - 팔로워 수 : 132
#
#
# 맘에 드신 분, 원하는 문구나 디자인 있으시면 디엠주세요.
# 최대한 고객님 뜻을 존중하겠습니다.
# 핸드메이드라서 동일한 제품이라도 똑같지는 않습니다.
# 또한 작은 기포가 있을수 있으니 양해바랍니다.
#
#
# - 인스타그램 아이디 : jjterrace
# - 팔로워 수 : 172
#
#
# 경기도 광주시 오포읍 신현로 73
# 월~토 09:30~21:00
# 일요일 10:00~21:00
# 휴무 매주 월요일
# 연락처 031-715-0394
#
#
# - 인스타그램 아이디 : grimd_studio
# - 팔로워 수 : 287
#
#
# EDITORIAL DESIGN STUDIO
# ·
# KAKAO _ 그림디자인
# AM 10 : 00 - PM 05 : 00
# ·
#
#
# - 인스타그램 아이디 : andme_cake
# - 팔로워 수 : 59
#
#
#  Flower cake&dessert
#  문의 : DM&
#  카카오톡채널 검색: 앤미케이크
#
#
# - 인스타그램 아이디 : lag_studio
# - 팔로워 수 : 171
#
#
#  Light and Glass 스테인드글라스
#  납이 없는 무연납(Pb free) 사용
#  DM / 아이디어스 / 네이버 스마트스토어 주문 가능
#  공방 오픈 준비 중
#
#
# - 인스타그램 아이디 : siltory_jewellery
# - 팔로워 수 : 26
#
#
# Siltory
# 실버에 나만의 이야기를 만드는 브랜드 입니다
# 주문제작 환영!
# 문의 디엠은 환영입니다
# #실토리 #siltory #쥬얼리 #반지 #실버반지
# #목걸이 #실버목걸이 #silver #silver925 #silverjewelry #silverring
#
#
# - 인스타그램 아이디 : keilyartstudio
# - 팔로워 수 : 1
#
#
# Or little creativity place
#
# For more info
#
#
# - 인스타그램 아이디 : paperbakery.co.kr
# - 팔로워 수 : 1,350
#
#
# www.paperbakery.co.kr
# [ 주 문 제 작 전 문 ]
# 기업초대장 ㅣ 수료증 l 캔들공방 l 사인보드
# 상담문의 바로가기
#
#
# - 인스타그램 아이디 : luco_and_love
# - 팔로워 수 : 10,453
#
#
# 쥬얼리 주문/제작 문의 DM or KAKAOTALK 카드결제가능
# worldwide shipping contact dm  paypal
# kakao id : soyoungieee
# 타투계정 @luco_and_tattoo
# 일상 @blueinthewinter
#
#
# - 인스타그램 아이디 : moodn_leathercraft
# - 팔로워 수 : 1,004
#
#
# moodn[무든]
# 저의 손길이 묻은 제품이 여러분의 손길이 닿아 더욱 빛이 나길 바랍니다.
# .
# 문의는 카카오톡에 ‘무든’ 검색하신 후 채팅방으로 문의 부탁드립니다.
#
#
# - 인스타그램 아이디 : lyn_storage
# - 팔로워 수 : 166
#
#
# 오프라인 : 스타필드시티 위례점
# #Lynstorage.com 네이버에 "린스토리지" 검색
# ▽수제 스와로브스키 주얼리&주문제작
#
#
# - 인스타그램 아이디 : yebinart
# - 팔로워 수 : 421
#
#
#  안동#예빈아트 (일일체험&일일특강)
#   #도자기핸드페인팅  토탈공예  페이스페인팅
#  캘리그라피  대한민국여성능력개발협회 #수강생모집
#
#
# - 인스타그램 아이디 : daily_fruits_2
# - 팔로워 수 : 126
#
#
# #산본카페 #산본컵과일 #컵과일
# Daily Fruits   ( 과일카페 )
# - 컵과일 , 과일도시락
# - 이벤트카빙 , 과일케이크
# 단체 /주문제작 문의는 DM
# 경기도 군포시 금정동 번영로 514 현대프라자 1층
#
#
# - 인스타그램 아이디 : hello.spring__
# - 팔로워 수 : 1,542
#
#
# • 정규클래스/원데이클래스/주문제작/원단판매
# • 경남 양산시 물금읍 화합5길 5
# •  카카오톡채널 - 안녕봄
#
#
# - 인스타그램 아이디 : ecoleange
# - 팔로워 수 : 1,264
#
#
#
#
#
# - 인스타그램 아이디 : notperfectbutbest
# - 팔로워 수 : 127
#
#
# Customizing&Handmade
# Contact > DM
# Business
# notperfectbutbest@gmail.com
#
#
# - 인스타그램 아이디 : bbbig05
# - 팔로워 수 : 15
#
#
# 𝑹𝒆𝒔𝒊𝒏𝒂𝒓𝒕⚘ #레진아트 #레진공예 #하트쉐이커
# ↓제품사진 및 상세안내는 링크를 확인해주세요
#
#
# - 인스타그램 아이디 : bin_loveben
# - 팔로워 수 : 1,105
#
#
# “인간은 욕망과 권태 사이를 시계추처럼 오가는 존재” -쇼펜하우어-
# #블랙푸들 #벤 #눈이이쁜아이
# 광고/홍보
# 매너가 사람을만든다^^ Kingsman
#
#
# - 인스타그램 아이디 : yebinart
# - 팔로워 수 : 421
#
#
#  안동#예빈아트 (일일체험&일일특강)
#   #도자기핸드페인팅  토탈공예  페이스페인팅
#  캘리그라피  대한민국여성능력개발협회 #수강생모집
#
#
# - 인스타그램 아이디 : hesil_hesil
# - 팔로워 수 : 22
#
#
# 뜨개 에어팟케이스/버즈케스 손수 한땀한땀 만들어요:)
#
#
# - 인스타그램 아이디 : corolaflower
# - 팔로워 수 : 2,009
#
#
# 꽃다발꽃바구니예약판매,화분선물판매,플라워클래스
# -
#  화훼장식기사,기능사/조경기능사
#  보존화자격1급/압화체험강사/동양꽃꽂이사범1급~초급
#  독일국가공인플로리스트마이스터
# -
#   플라워클래스 상시모집중
#  031.526.7922
#  클래스•꽃상품주문예약문의
#
#
# - 인스타그램 아이디 : mirinae_handmade
# - 팔로워 수 : 8
#
#
#  스토어팜  본계정 @milinae_handmade
#
#
# - 인스타그램 아이디 : cafe_gwasilwon
# - 팔로워 수 : 131
#
#
#
#
# - 인스타그램 아이디 : minkyunge_cho
# - 팔로워 수 : 326
#
#
# 달빛공방
# #원목가구 #인테리어 #원목가구공방 #DIY교육
# #자유학기제 체험강좌 #진로체험처
# #톨페인팅공방 #친환경페인트 #던에드워드페인트시공
# #fauxpainting #speicalpaint #artpainting  #포터스페인트 #친환경코디네이터
#
#
# - 인스타그램 아이디 : smoky_daily_
# - 팔로워 수 : 12,422
#
#
# #커스텀신발 #커스텀클래스 #커스텀선물 #마카쥬
#   아이디어스 작가 : smoky
# 원데이클래스 문의 @custom_class_
#   슈즈 커스텀 스토어   [ 문의:DM ]
#
#
# - 인스타그램 아이디 : rococosofa.co.kr
# - 팔로워 수 : 5,806
#
#
# Timelss & Basic Furniture
# 세월이 흘러도 변치 않는 가구 브랜드
# -
#
#
# - 인스타그램 아이디 : _punct._
# - 팔로워 수 : 668
#
#
# ✿
# Leather goods for style.
# 자체제작(in-house production)
#
#
# - 인스타그램 아이디 : pimpollo314
# - 팔로워 수 : 697
#
#
#
#
# - 인스타그램 아이디 : siz_acc
# - 팔로워 수 : 25
#
#
# 스토어 오픈  무료배송 진행 중 (✿◡‿◡)
#
#
# - 인스타그램 아이디 : fluke_studio
# - 팔로워 수 : 170
#
#
# FLUKE "특별함을 담는 공간"
#   레진아트 @fluke_resin
#   캔들 @fluke_candle
#  클래스
# 원데이 클래스/ 취미반/ 소품샵 준비중
#   문의 : DM/카카오톡ID: FlukeStudio
#
#
# - 인스타그램 아이디 : drawing_myday
# - 팔로워 수 : 0
#
#
# 문의 및 주문은 하이라이트 확인 후에 dm주세요 ♡︎ !
# _
# #라인드로잉 #주문제작 #그림 #그림문의 #일러스트
#
#
# - 인스타그램 아이디 : nuricom815
# - 팔로워 수 : 12
#
#
#
#
# - 인스타그램 아이디 : lillico__
# - 팔로워 수 : 12,958
#
#
# LILLICO
# 서울시 용산구 이태원동 118-5번지
#
#
# - 인스타그램 아이디 : j.leather__
# - 팔로워 수 : 105
#
#
# #부산가죽공방 #부산가죽: yeonji atelier
#   재미있고 쉬운 #원데이클래스
#   손바느질.미싱교육 모두 가능합니다
# #주문제작
# #가방 #클러치 #주문제작
#
#
# - 인스타그램 아이디 : joli_kokkok
# - 팔로워 수 : 170
#
#
# ∗ 나만의 소품으로 특별해지는 공간  ︎
# ∗ 𝘾𝙪𝙨𝙩𝙤𝙢 𝙀𝙢𝙗𝙧𝙤𝙞𝙙𝙚𝙧𝙮
# ∗ #졸리콕콕 #커스텀자수 #대구커스텀자수 #자수맛집 #성서계대
# ∗ 프로필링크 눌러 문의 및 구매해주세요
#
#
# - 인스타그램 아이디 : keilyleeart
# - 팔로워 수 : 304
#
#
#  TIKTOK - keilylee1
#  ETSY - Keilyartstudio
#  IDUS - Sangsangart
#  Youtube
#
#
# - 인스타그램 아이디 : art.pie_
# - 팔로워 수 : 190
#
#
#  ️반려견, 반려묘 초상화 주문제작
#  ️인물 초상화 주문제작
#  ️원데이 클래스 진행
#  ️개인 작품활동
# .
# 스마트스토어 : http://smartstore.naver.com/tayo_200
# 아이디어스 : idus.com/art_pie
#
#
# - 인스타그램 아이디 : cozyblossom
# - 팔로워 수 : 1,045
#
#
# 이야기가 있는 꽃 정원 카페
# blooming in the garden
# flower & cafe
# 디자이너가 제안하는 플라워디자인샵
# 주문문의 카카오톡 cozyblossom
# #감성꽃집 #식물인테리어
# #호평동꽃집 #남양주꽃집
# #평내동꽃집 #플라워카페
# 호평로 60번길 7,1층
#
#
# - 인스타그램 아이디 : honggung_jewelry
# - 팔로워 수 : 241
#
#
# 단장하는 분들을 위한 특별한 핸드메이드 쥬얼리샵
# 한복&웨딩 장신구
# 원석수공예전문점
# .
# 본 사이트 ︎
# https://www.honggung.com
# .
#  레터링.파티.헬륨풍선 @in.honggung
# .
#  문의사항은 카카오톡플러스친구 ‘홍궁’ 추가!
# .
# 네이버 주문
#
#
# - 인스타그램 아이디 : 3rdhand_jewelry_studio
# - 팔로워 수 : 438
#
#
# 서드핸드_운서동주얼리공방
# 주문제작주얼리 #custommade
# 원데이,취미,전문강사 과정 수강문의 0507 1324 9992
# #영종도반지공방 #영종도은공방 #반지공방
# #graduatejeweler
# #artclaysilver instructor
#
#
# - 인스타그램 아이디 : flower_eum
# - 팔로워 수 : 398
#
#
# 경상북도 경산시 중방로57(중방동)
# 문의 : 010-2331-2021
# #경산꽃집 #중방동꽃집 #경산꽃배달
# 월~금: 9시-19시, 토:12시-18시, 일•공휴일은 휴무입니다
# 전화예약주문 ️ 경산배달 ️ 주문예약 ️
#
#
# - 인스타그램 아이디 : gagaahome
# - 팔로워 수 : 9,418
#
#
# 아이들의 소중한 꿈과 희망을 담은 가구
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀
#   매장 정보 - 스토리 하이라이트 확인
#   공식 쇼핑몰
#
#
# - 인스타그램 아이디 : ata_dolls
# - 팔로워 수 : 66
#
#
# #인형작가
# 친환경 핸드메이드 베이비 첫 애착인형
# 자체 디자인 애착인형
# 옷 갈아입는 애착 인형
# 브라이스 인형 드레스
#
#
# - 인스타그램 아이디 : silver_luna_flowerstudio_
# - 팔로워 수 : 2,426
#
#
#  부케액자/부케유리돔/청첩장액자/드로잉액자
#  서울 강남 신논현역 위치
#  상담문의
# •카카오톡채널: 실버루나스튜디오
# •문자: 010.3290.9333
#  더 자세히 알아보기
#
#
# - 인스타그램 아이디 : leather__wan
# - 팔로워 수 : 719
#
#
# 가죽제품 주문제작
# H.P_010.8724.1730
# Kakaotalk_adrella0
# 네이버스마트스토어_ https://m.smartstore.naver.com/leatherwan
# 아이디어스_ https://www.idus.com/search?word=레더완
#
#
# - 인스타그램 아이디 : _da.jung
# - 팔로워 수 : 974
#
#
#
# 수제비누와 소품 / &무대디자이너
# ⠀
#  지구와 나를 위한 건강한 비누 만들기
# ⠀
# 주문제작,원데이클래스 문의
# 카카오톡 •작업실다정•
# ⠀
# 제조업•책임판매업 등록 업체
# ⠀
#   스토어팜에서 구매
#
#
# - 인스타그램 아이디 : humming_factory
# - 팔로워 수 : 972
#
#
#  [취미반/7세반/초등반/중등반/원데이클래스]
#  1회 체험수업 가능 (유료)
#  인형,브로치,반려동물초상화 주문제작
#   @cat_ppoddo ( )
#
#
# - 인스타그램 아이디 : hzcrntgy873752
# - 팔로워 수 : 17
#
#
#  대구출장안마 충남출장안마 광주출장안마
#  유흥업소 애인만남 애인대행
#  출장업소 출장대행 출장안마
#  안마후기 출장안마후기 마사지후기
#
#
# - 인스타그램 아이디 : _kusniz_
# - 팔로워 수 : 160
#
#
# Tam하다의 스마트스토어  쿠스니즈 준비중
# 핸드메이드 주얼리/마크라메/클래스
# 시크빈티지 스타일 편집샵
# 일상@tamsugi0202
# 문의 : 카카오톡 tam2003/카카오채널 탐악세사리
#
#
# - 인스타그램 아이디 : flowershop_grandbleu
# - 팔로워 수 : 37
#
#
# 그랑블플라워 인천 연수구 동춘동 예쁜 꽃집입니다 인천,서울,경기지역 배송가능합니다. 영업시간 오전10시부터 오후9시 010-6775-5856
#
#
# - 인스타그램 아이디 : art_memoria_
# - 팔로워 수 : 51
#
#
# #트레이싱
# #창작
# -----------------------------------------------------
#
#
# - 인스타그램 아이디 : rea11y_just
# - 팔로워 수 : 285
#
#
# ⠀
# ⠀
# ⠀
# 가격문의 및 주문은 DM으로 연락주세요
#
#
# - 인스타그램 아이디 : risi_o_
# - 팔로워 수 : 3,190
#
#
# ❥ 쥬얼리 • 잡화 쇼핑몰 입니다 ❥
# 𝑻𝒉𝒂𝒏𝒌 𝒚𝒐𝒖, 𝒆𝒗𝒆𝒓𝒚𝒐𝒏𝒆.
# :-( DM은 확인이 어렵습니다
#
#
# - 인스타그램 아이디 : hanssem_domus
# - 팔로워 수 : 1,042
#
#
# 최상의 라이프를 추구하는
# 프리미엄 수입가구
#   포토후기 이벤트
# 한샘도무스 홈페이지 내에 리뷰 작성
#  DM 상담 가능 시간
# 평일 : 오전 8시~ 오후 5시 (주말제외)
# 답변이 늦어질 수 있는 점 참고 부탁드립니다.
#
#
# - 인스타그램 아이디 : leathers_1
# - 팔로워 수 : 183
#
#
# #가죽공예 #가죽가방 #가죽지갑
# #제품문의 #가격문의는DM으로주세요
# #가죽가방판매 #가죽지갑판매
# #핸드메이드 #가방판매 #지갑판매
# #주문제작 #leathers #ring
# 모든작업은 꼼꼼히 #수작업 합니다
# #가죽파우치
# 유튜브 #가죽꼼꼼튜브 구독과 좋아요~눌러주세요^^
#
#
# - 인스타그램 아이디 : noey_hm
# - 팔로워 수 : 176
#
#
# ㅤㅤ
# 하루의 작은 순간이 되고 싶은, 노이
# 𝐍𝐨𝐞𝐲 𝐇𝐚𝐧𝐝𝐦𝐚𝐝𝐞 𝐒𝐡𝐨𝐩 _ 𝐅𝐚𝐛𝐫𝐢𝐜 & 𝐀𝐜𝐜
# ㅤㅤ
#
#
# - 인스타그램 아이디 : flower_eum
# - 팔로워 수 : 398
#
#
# 경상북도 경산시 중방로57(중방동)
# 문의 : 010-2331-2021
# #경산꽃집 #중방동꽃집 #경산꽃배달
# 월~금: 9시-19시, 토:12시-18시, 일•공휴일은 휴무입니다
# 전화예약주문 ️ 경산배달 ️ 주문예약 ️
#
#
# - 인스타그램 아이디 : olive_story_
# - 팔로워 수 : 317
#
#
# 문의는 010.7545.6983
# 카카오톡플러스친구:올리브의린넨스토리
# DM  알림 안떠요 ㅠ
#  맞춤제작전문
# #린넨 #핸드메이드 #린넨원피스 #패션 #오더메이드 #맞춤제작
#
#
# - 인스타그램 아이디 : honesto.furniture
# - 팔로워 수 : 212
#
#
# HONESTO.furniture
# 창원가구공방
# 원목소품 / 원데이클래스
# 10AM - 7PM
# 문의는 DM 또는 유선으로 하고있습니다 :)
#
#
# - 인스타그램 아이디 : gu9276
# - 팔로워 수 : 428
#
#
# #돌잡이연필 #돌잡이용품 #돌잡이
# #야외용의자
# #스툴의자 #나무의자 #원목의자 #나무스툴
# #칼도마 #빵도마 #나무도마 #원목도마
# #구례 #목수 #구목수 #구례구목수 #구례목수구목수
# #나무플레이트
# #대나무도마
# #원데이클래스수강
# #맨투맨월수강
# #주문제작
#
#
# - 인스타그램 아이디 : waple_woodartwork
# - 팔로워 수 : 1,670
#
#
# 수업, 출강, 작업 시 답변이 좀 느릴 수 있습니다.
# 양해부탁드려요
# 서울 성동구 성수동1가
# 수업 ,주문 제작 문의
# Tel : 02-467-3688
# Kakao : 와플목공방
# #원데이클래스 #주문제작 #기업출강 #목공방
#
#
# - 인스타그램 아이디 : gamseong_official
# - 팔로워 수 : 761
#
#
# 세상에 단 하나뿐인
#  의미있는 메세지 상품을 선물해요
#  감성장인은 #주문제작 1개부터 가능
# .
# .
# #여친선물 #남친선물 #답례품
# #굿즈제작 #드로잉 #감성굿즈 #일러스트
# #레어템 #득템
#
#
# - 인스타그램 아이디 : ratelier_s
# - 팔로워 수 : 192
#
#
# -라틀리에S 공간
# -세 여자의 작업공간
# -핸드메이드 작업
# -원데이클래스,DIY 문의
#
#
# - 인스타그램 아이디 : atelier_gemma
# - 팔로워 수 : 149
#
#
# 금속공예가
#
#
# - 인스타그램 아이디 : salon_fleuri
# - 팔로워 수 : 1,336
#
#
# 꽃 작업실 art flower atelier
#
# 원데이 안내
#
#
# - 인스타그램 아이디 : goribyruga
# - 팔로워 수 : 70,413
#
#
#  ️2021년 5년연속 브랜드파워대상
#  ️2018년 소비자선호브랜드대상
#  ️2017년 가치경영대상
#  ️Jewelry디자인학 박사학위
#  ️보석감정사
#  ️쇼룸방문예약 070-7607-0607
#
#
# - 인스타그램 아이디 : douleatherwork
# - 팔로워 수 : 220
#
#
# 1인 가죽공예
# 제작 문의 DM
#
#
# - 인스타그램 아이디 : fillup1131
# - 팔로워 수 : 162
#
#
#
#
# - 인스타그램 아이디 : song__wood
# - 팔로워 수 : 59
#
#
# 원목마그넷 수제도마 원목소품 원목가구 전문
# 문의 010.2005.5519
# 네이버-송우드검색 톡톡문의환영
#
#
# - 인스타그램 아이디 : greedacustom
# - 팔로워 수 : 14
#
#
# 주문제작 타프 사이드월 어닝 스크린 플라이 메쉬창 투명창 TPU창
#
#
# - 인스타그램 아이디 : artist.kyury
# - 팔로워 수 : 595
#
#
# Handmade Art
# Hand Painting
# 주문 문의는  DM
# #핸드메이드 #핸드페인팅 #페브릭아트 #수예 #art #handdrawing #handpainting #수공예 #수제아트 #artist
#
#
# - 인스타그램 아이디 : doore_caligrafia
# - 팔로워 수 : 1,120
#
#
# 두레, 阧鶆
# 전각, 수제도장, 캘리그라피
#  전각,인장 --> @doore_seal 두레새김
#  작품 주문 • 문의 ...DM 또는 카톡
#
# #두레새김#전각#수제도장#篆刻#印章
# #doore_seal#engraver
# #두레글씨#캘리그라피#멋진먹글씨
# #calligraphy
#
#
# - 인스타그램 아이디 : mamelda_biz
# - 팔로워 수 : 448
#
#
#  Only one 디자인 소품 [ 마멜다 ]
#  밀리너리_모자. 헤드피스
#  촬영소품 디자인. 제작. 대여 및 협찬
# #MAMELDA #millinery #headpiece #hat #fashion_accessories #handcrafted
# .
#  유튜브
#
#
# - 인스타그램 아이디 : flowershop_grandbleu
# - 팔로워 수 : 37
#
#
# 그랑블플라워 인천 연수구 동춘동 예쁜 꽃집입니다 인천,서울,경기지역 배송가능합니다. 영업시간 오전10시부터 오후9시 010-6775-5856
#
#
# - 인스타그램 아이디 : radice0754
# - 팔로워 수 : 641
#
#
#  라디체(공장직영/자체공방/리셋팅/직접세공)
# 은커플링/캐럿셋팅/위탁판매모집/프로포즈반지/커플링만들기체험
#  셀럽제품들을 싸게 만날 수 있는 제작소
# 그녀들의 품격을 한껏 높여 줄 패션의 완성!특별한 주얼리
# 문의는010.8853.8128로 문자나 카톡주심 젤 빠르세요~^^
#
#
# - 인스타그램 아이디 : keilyartstudio
# - 팔로워 수 : 1
#
#
# Or little creativity place
#
# For more info
#
#
# - 인스타그램 아이디 : doran_doran_nail
# - 팔로워 수 : 598
#
#
#  ️붙이는 #수제네일팁 입니다
#  ️1:1맞춤 핸드메이드 제품입니다 ◡̈
#  ️네일국가자격증  ️
#  ️카카오톡 플러스친구 - 수제네일팁, 도란도란
#  ️문의는 카톡이나 DM으로 해주세용
#  ️디자인 무단사용 금지
#  ️주문은   링크   로 부탁드려요 ◡̈
#
#
# - 인스타그램 아이디 : flower_eum
# - 팔로워 수 : 398
#
#
# 경상북도 경산시 중방로57(중방동)
# 문의 : 010-2331-2021
# #경산꽃집 #중방동꽃집 #경산꽃배달
# 월~금: 9시-19시, 토:12시-18시, 일•공휴일은 휴무입니다
# 전화예약주문 ️ 경산배달 ️ 주문예약 ️
#
#
# - 인스타그램 아이디 : mshee_official
# - 팔로워 수 : 1,276
#
#
# 영문 필기체 레터링 주얼리
# 1:1 맞춤 주문제작
#   구매는 메세지(DM)문의
#  제작기간 3일소요(공휴일 제외)
#  ️소재설명 꼭 읽어주세요(하이라이트 참고)
#
#
# - 인스타그램 아이디 : monellozio
# - 팔로워 수 : 856
#
#
# 개구쟁이 우리 아이들을 위한 선물
# 비즈팔찌, 유아동복도 있어요
# 문의&주문   DM 받아요
#
#
# - 인스타그램 아이디 : pomlapoleon
# - 팔로워 수 : 22,548
#
#
# 폼라폴레옹 1세   포메먼치킨
# ⠀
# Career Woman   | Cat&Dog Butler  | ⠀
# Jardin de l'Hôtel de Shine ⠀
#
#
# - 인스타그램 아이디 : s_palette_official
# - 팔로워 수 : 856
#
#
# 나만의 가치를 표현하는
# personnality
# 여유로운 일상을 누리는
# Daily
# 사랑하는 사람 그리고
# 반려동물과 함께하는
# Lovely
# 오직, 당신만을 위한
# 프리미엄주얼리
# #에스팔레트
#
#
# - 인스타그램 아이디 : keyou.jewelry
# - 팔로워 수 : 936
#
#
# *키유는 열쇠와 자물쇠 모양을 모티브로 디자인과정을 거쳐서 왁스카빙으로 작업후 완성되는 핸드크래프트 실버주얼리입니다:)
# *1:1 오더메이드 주문제작! *DM문의
#
#
# - 인스타그램 아이디 : 3dstory.kr
# - 팔로워 수 : 52
#
#
#  최적의 시제품 제작 파트너
# -목업
# -미니어처
# -피규어
# -트로피
# -모형
# -3D모델링
# -3D프린팅
#  문의는 DM, 또는
#
#
# - 인스타그램 아이디 : eun_h_ake
# - 팔로워 수 : 172
#
#
#  주문제작 레터링떡케이크
#  김포구래역 4번출구
#  주문상담은 카카오톡에서 은헤이크를 검색해주세요
#
#
# - 인스타그램 아이디 : honggung_jewelry
# - 팔로워 수 : 241
#
#
# 단장하는 분들을 위한 특별한 핸드메이드 쥬얼리샵
# 한복&웨딩 장신구
# 원석수공예전문점
# .
# 본 사이트 ︎
# https://www.honggung.com
# .
#  레터링.파티.헬륨풍선 @in.honggung
# .
#  문의사항은 카카오톡플러스친구 ‘홍궁’ 추가!
# .
# 네이버 주문
#
#
# - 인스타그램 아이디 : gawaleather
# - 팔로워 수 : 2,459
#
#
# 가죽제품 판매 및 주문제작 전문 작업실입니다.
# 카카오톡:가와레더
# 블로그: http://www.gawa.co.kr
# 네이버:gawaleathers
#
#
# - 인스타그램 아이디 : keilyartstudio
# - 팔로워 수 : 1
#
#
# Or little creativity place
#
# For more info
#
#
# - 인스타그램 아이디 : manbuk06
# - 팔로워 수 : 335
#
#
# 만북 캘리그라피
# ⠀
#  주문제작/행사/교육 의뢰 등
#  캘리그라피 지도사1급
#  모든문의: DM / 댓글 / e-mail
#  : lucy2403@naver.com
#
#
# - 인스타그램 아이디 : batji_nail
# - 팔로워 수 : 168
#
#
#  2월 14일 오후10시까지 리그램 이벤트중이에요
#  1:1 맞춤제작 수제팁/로고네일맛집
#  주문문의 DM 전 하이라이트 필독해주세요~
#  3만원이상 구매시 무료배송(배송비:3000원)
#  팁 쉐입 변경 가능
#
#
# - 인스타그램 아이디 : jiyeon_0211_
# - 팔로워 수 : 258
#
#
#
# 지연’s 스토리
#
# DM 잘 안봐요...
#
#
# - 인스타그램 아이디 : around.j_candle.soap
# - 팔로워 수 : 1,430
#
#
# Around.j 어라운드제이
# ( 예약제공방 )
# 캔들.천연비누
# KCCA(아로마캔들.캔들아티스트)
# KAIA(디자인비누 일반강사)
# 맞춤형클래스
# 답례품.주문제작
# HP: 010.2765.1111
# Kakao:jongmi0
# 카카오채널:어라운드제이
# 주차ok,봉천역3분
#
#
# - 인스타그램 아이디 : agasewing
# - 팔로워 수 : 170
#
#
#  손끝으로 전하는 사랑
#
#
# - 인스타그램 아이디 : _sian.7
# - 팔로워 수 : 1,038
#
#
#  ️아이디어스 작품,작가검색 김시안
#  ️주문제작 및 포슬린 페인팅 수업
#  ️문의는 DM 주세영
#
#
# - 인스타그램 아이디 : jelly_d27
# - 팔로워 수 : 2
#
#
# 안녕하세요 젤리디자인입니다.
# 디자인스티커 네임스티커 방수네임스티커
# 디자인행거 주문제작/대량주문 가능
# 카카오플러스 : 젤리디자인  검색해주세용:)
#
#
# - 인스타그램 아이디 : byeolkkot_calli
# - 팔로워 수 : 109
#
#
# 별꽃 캘리그라피 대표
# 신아 이영민 calligrapher
#  #캘리그라피행사 #학교, 기업출강 #원데이
#  # DM문의 #수원 #세류동
# *평생교육전문강사협회
# 캘리그라피 / POP
# *한국디자인미술교육진흥회
# *대한서예협회 수원시지부
#
#
# - 인스타그램 아이디 : ellymaker_shop
# - 팔로워 수 : 86
#
#
# 엘리메이커 핸드메이드 주문제작
# *아크릴 도장 (비누도장, 도예도장)
# *스크래퍼 주문제작 *가죽소품 주문제작
# @ellymaker @ystudio_soap 도장참고
# Kakao_loveboss1 /디엠 환영
#
#
# - 인스타그램 아이디 : seangraphic.studio
# - 팔로워 수 : 65
#
#
# ⊹ 𝗗𝗲𝘀𝗶𝗴𝗻 𝗴𝗼𝗼𝗱𝘀
# ⊹ 𝑏𝑒𝑦𝑜𝑛𝑑 𝑡ℎ𝑒 𝑑𝑟𝑒𝑎𝑚, 𝑏𝑦 𝑦𝑜𝑢𝑟 𝑠𝑖𝑑𝑒.
# ⊹
#
#
# - 인스타그램 아이디 : lej0235
# - 팔로워 수 : 58
#
#
# 이은주(Atistorying)
# #아티스토리 대표
# #공예배우미협동조합 대표이사
# #카페더로즈
# #여성취창업전문교육기관
# #카페창업 #디저트  #수제청
# #진로체험 #창의체험 #자유학기제
# #리본아트 #선물포장 #보자기아트
# #전문가클래스
# #핸드메이드 #답례품 #키트 주문제작
#
#
# - 인스타그램 아이디 : leather_chimera
# - 팔로워 수 : 14,748
#
#
# Leather Crafter
# 대구 중구 향촌동 10-8번지 정원식당 2F
# '수강문의' 및 '지갑 및 각종 소품 주문제작'
#  +82 10-7712-5203
# Open KakaoTalk
#
#
# - 인스타그램 아이디 : k_gallery_kwang_present
# - 팔로워 수 : 235
#
#
# 일상에 한국 을 담은 선물
# -----
# 입점
# 망원동 [유어굿즈]
# [그림민화랑] 온라인 샵
# ㅡ
# @k_gallery_kwang
# -----
# #한국 #굿즈 #KOREA #GOODS
# [Portfolio]
#
#
# - 인스타그램 아이디 : gong__gan
# - 팔로워 수 : 610
# 나무반지 공방
# ♧ 100% 사전예약 / 디엠 전화예약
# ♧ 매주 월,화,목,금,토,일 클래스 운영
# ♧ AM 11:00~PM 9:00
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# #나무반지 #원데이클래스 #주문제작
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
#  예약문의 바로가기
#
#
# - 인스타그램 아이디 : leather_most
# - 팔로워 수 : 3,171
#
#
# 서울시 동대문구 신설동 난계로244 1층
# Nangyero 244, Dongdaemun-gu, seoul.
#  010-8636-1779
# #레더모스트 #앱송가죽 #레더모스트양면가죽#레더모스트러닝가죽 #양면가죽 #가죽공장운영
#
#
# - 인스타그램 아이디 : macrame0_0
# - 팔로워 수 : 41
#
#
# 마크라메 제작&문의(핸드메이드)
# ⚘소소한 일상&소통
# ⚘집꾸미기,취미, 인테리어,
# ⚘제품 문의/가격 문의는 DM으로 부탁드려요^^
#
#
# - 인스타그램 아이디 : leather_chimera
# - 팔로워 수 : 14,748
#
#
# Leather Crafter
# 대구 중구 향촌동 10-8번지 정원식당 2F
# '수강문의' 및 '지갑 및 각종 소품 주문제작'
#  +82 10-7712-5203
# Open KakaoTalk
#
#
# - 인스타그램 아이디 : egna.masterpiece
# - 팔로워 수 : 291
#
#
# 𝘼 𝙏𝙞𝙣𝙮 𝙈𝙖𝙨𝙩𝙚𝙧𝙥𝙞𝙚𝙘𝙚 𝙊𝙣 𝙔𝙤𝙪𝙧 𝘽𝙤𝙙𝙮
# Design beyond aesthetics
# Carefully handcrafted with love
# •made to order •made by hand
# For inquiries please dm or email
#
#
# - 인스타그램 아이디 : cupiros_young
# - 팔로워 수 : 575
#
#
# 떫은 감이 곶감 될 때까지
# 핸드메이드 레진가게 큐피로스
#
#
# - 인스타그램 아이디 : kim_woodm
# - 팔로워 수 : 202
#
#
# 망고 남집사의 목공이야기
# 망고의 일상은 @mango_0328__여기로
# 반려동물가구 원목도마 짜맞춤가구
# 문의는 DM 부탁드려요
# 네이버 스토어 링크는 하단에!!
#
#
# - 인스타그램 아이디 : evighet_leather
# - 팔로워 수 : 10,322
#
#
# Leather craft Brand
# 특별한날 특별한분께 특별한선물을
# 제품, 클래스 (정규, 원 데이) 문의
# 상담은 하단에 오픈 채팅방을 이용해주세요.
#
#
# - 인스타그램 아이디 : leathers_2
# - 팔로워 수 : 56
#
#
# #제품문의 #가격문의는DM으로 주세요
# #가죽가방판매 #가죽지갑판매
# #바느질 #핸드메이드 #가방판매 #지갑판매
# #주문제작 #leathers #ring
# 모든작업은 꼼꼼히 #수작업 합니다
# #가죽파우치 #가죽카드지갑
# 유튜브 #가죽꼼꼼튜브^^ 구독과 좋아요 ~눌러주세요 ^^
#
#
# - 인스타그램 아이디 : with.goods
# - 팔로워 수 : 6,849
#
#
# 3,000여명의 창작자와 함께하는 굿즈 마켓 레트로 감성 포토 캘리그라피 등 다양한 리빙소품이 가득해요. 나만의 굿즈제작, 단체굿즈제작도 가능! #유리컵제작 #머그컵제작 #패브릭포스터제작 #코스터제작 #텀블러제작 #소량부터대량까지
# 문의는 카카오톡 @위드굿즈
#
#
# - 인스타그램 아이디 : tbmjleather
# - 팔로워 수 : 2,088
#
#
# tbmj leather _
#
# made by hand
#
#
# - 인스타그램 아이디 : kkanga777
# - 팔로워 수 : 97
#
#
# 다육이야기...다담 (효행로704)010-8270-7443
#
#
# - 인스타그램 아이디 : callisohoney_store
# - 팔로워 수 : 172
#
#
# 고객님들께 전한 정성을 기록합니다
# 본계정  @calli_sohoney
# .
#  네이버쇼핑 캘리액자 상위랭크
#  아이디어스 입점 작가
#  에이블리 입점
# .
#  캘리그라피 소품 주문제작
# .
# 문의는 DM, 카톡 플친 캘리쏘허니로
#  상품도용금지
#
#
# - 인스타그램 아이디 : haein_shibaiun.leo
# - 팔로워 수 : 545
#
#
# 2013.08.19
# 2018.09.30
# 2019.05.08  레오 #시바견 #대구시바견
#
#
# - 인스타그램 아이디 : cheoldeulda
# - 팔로워 수 : 453
#
#
# 금속공예기법으로 만드는 동식기제작 공방입니다.
# 제품문의는 DM 부탁드립니다.
# 기성품과 가격 차이가 있습니다.
# 수작업이다보니 하루 제작수량이 한정됩니다.
# 문의시 참고해주세요 ^^
#
#
# - 인스타그램 아이디 : drawing_myday
# - 팔로워 수 : 0
#
#
# 문의 및 주문은 하이라이트 확인 후에 dm주세요 ♡︎ !
# _
# #라인드로잉 #주문제작 #그림 #그림문의 #일러스트
#
#
# - 인스타그램 아이디 : hardwoodroom
# - 팔로워 수 : 3,747
#
#
# Since-1996
# 대구 감성핸드메이드
# 짜맞춤 가구공방.
# 주문제작전문공방..수강생 항시 접수 받고 있어요.
# T.010~3520~6340.
#
#
# - 인스타그램 아이디 : crescent_leather
# - 팔로워 수 : 3,521
#
#
# leathercraft & designgoods
# .
# operating hours
# sunday off
#
#
# - 인스타그램 아이디 : chaelee.tt
# - 팔로워 수 : 3,130
#
#
# Seoul,Korea
# 2월 예약가능합니다
# 미성년자는 작업해드리지 않습니다 ~
# 당분간은 조금 낮은금액으로 작업해드리니 편하게 문의주세요
#  문의는 오픈카톡링크를 눌러주세요
#
#
# - 인스타그램 아이디 : lej0235
# - 팔로워 수 : 58
#
#
# 이은주(Atistorying)
# #아티스토리 대표
# #공예배우미협동조합 대표이사
# #카페더로즈
# #여성취창업전문교육기관
# #카페창업 #디저트  #수제청
# #진로체험 #창의체험 #자유학기제
# #리본아트 #선물포장 #보자기아트
# #전문가클래스
# #핸드메이드 #답례품 #키트 주문제작
#
#
# - 인스타그램 아이디 : bong_pot
# - 팔로워 수 : 160
#
#
# 김포시 김포대로1199 일봉도예
# 도•소매 가격문의 DM주세요
# #수제화분 #다육화분 #도자기주문제작
#
#
# - 인스타그램 아이디 : tmw_silver
# - 팔로워 수 : 853
#
#
# 천안금속공예공방.실버주얼리판매.반지만들기. 원데이클래스.취미반.레이저각인.주문제작
#   13:00~20:00
#   010.3772.0810 예약필수 :)
#
#
# - 인스타그램 아이디 : sea_neul
# - 팔로워 수 : 1,871
#
#
# 교림공방
# 교림매니저_새늘
# 모스틀계정 @scandiamossteul
# 스칸디아모스 ,프리저브드플라워
# 010-4875-7087
# 문의는 여기로 해주세요
#
#
#
# - 인스타그램 아이디 : hi.stamp_official
# - 팔로워 수 : 237
#
#
# 스탬프 제작업체인 "안녕, 스탬프"입니다.
# 다양한 스탬프를 스토어팜을 통하여 판매합니다.
# 좋은 품질의 다양한 스탬프로 찾아뵙겠습니다.
# 네이버 검색창에 "안녕스탬프" 를 검색해주세요!
# ⠀⠀⠀⠀
#  하단의 링크를 이용하셔도 됩니다 :-)
#
#
# - 인스타그램 아이디 : avva_store_
# - 팔로워 수 : 4
#
#
# 주식회사 아바광고의 네이버스토어 아바상점입니다.~
# #미니등신대 #아크릴등신대 #키링제작판매 #스티커제작 #스티커제작판매 #등신대제작 #자석제작 #주문제작 #주문제작커스텀 #별에별걸 #파는곳 #스티커 #사진자석
#
#
# - 인스타그램 아이디 : sangmi_jeong
# - 팔로워 수 : 134
#
#
# 그녀들의 바느질이 시작되는곳
# #홈패션배울수있는곳#소잉
# #재봉틀공방#취미생활#배움#일상
# 수업문의 063)241-0209
# 전주시 덕진구 인후동1가841-10번지 1층
#
#
# - 인스타그램 아이디 : jj__s2__drawing
# - 팔로워 수 : 401
#
#
# 가장 예쁜 순간을 그림으로 남겨드려요
# 드로잉 문의 DM
#
#
# - 인스타그램 아이디 : hellodamoa
# - 팔로워 수 : 86
#
#
#  스티커 주문제작
#  시트지스티커  @dodadakong
#  카카오채널 디에이모아
#  스토어팜 바로가기는
#
#
# - 인스타그램 아이디 : topla_rin
# - 팔로워 수 : 1,114
#
#
#  JHA 하바리움협회 충남지정교육처
#  한국 최초 일본하바리움협회 오리지널 레슨 등록 강사
#  2020 일본-한국 하바리움 어워드 한국 작품 2위 수상
#  미술심리, 아동심리, 원예심리, 감정노동관리 1급
#  네이버, 솜씨당, 아이디어스 ☞ 토플라
#   스마트스토어
#
#
# - 인스타그램 아이디 : nuricom815
# - 팔로워 수 : 12
#
#
#
#
# - 인스타그램 아이디 : luceinaltis_0
# - 팔로워 수 : 347
#
#
# #양주가죽공방
# #미싱수업#미싱공방#지갑제작
# #수강문의#초중고급클래스#정규강의#원데이클레스
# ♡특수피혁 수제 지갑&핸드백
# 브랜드 루체인알티스♡
# #루체인알티스#지갑그램
# #수제지갑#주문제작
# #악어가죽#파이톤가죽#타조가죽#일상#맛팔#선팔#소통해요#덕정길57
#
#
# - 인스타그램 아이디 : re_born2021
# - 팔로워 수 : 33
#
#
#   영업시간
# 월~토 11:00~18:00
#   카카오채널: reborn2021
#  리본케이크 (검색)
#  DM도 문의 가능합니다
#
#
# - 인스타그램 아이디 : steeldeco_collection
# - 팔로워 수 : 48
#
#
# 스틸데코 철재장식 인테리어
#
#
# - 인스타그램 아이디 : llo46oll
# - 팔로워 수 : 292
#
#
#
#
#
# - 인스타그램 아이디 : banezzage_official
# - 팔로워 수 : 437
#
#
# twinkle and lovely
# 반짝이는 반려가족 주얼리 브랜드 반이짝이입니다
#
#
# - 인스타그램 아이디 : candle_buen_olor
# - 팔로워 수 : 595
#
#
# 캔들브에놀로...칠성로길37
#
#
# - 인스타그램 아이디 : pandora.kr_
# - 팔로워 수 : 498
#
#
# 고객에 맞게 맞춤제작해드리는 판도라피아
#  02)744-5200, 010-7227-8099
# 실시간 카톡상담가능
# 카톡ID,etsy:pandorapia
#  굿즈 뱃지 디자인 포트폴리오
# @logomark.kr/@13dog11cat
# 유튜브 bit.ly/2WLXuB1
#
#
# - 인스타그램 아이디 : ggom._.ji
# - 팔로워 수 : 6
#
#
# 안녕하세요:) 꼼지락샵입니다!
# 프로필 링크로 들어오시면 더 많은 상품을 보실 수 있습니다.
#  관련 문의사항은 DM으로 보내주세요!
#
#
# - 인스타그램 아이디 : metal_library_
# - 팔로워 수 : 240
#
#
# 철들지 않는 철쟁이 /영등포구 경인로 755 2층
# @instantgapla
# @smokekirin
# @gamsung18k
#
#
# - 인스타그램 아이디 : rosee_claire
# - 팔로워 수 : 865
#
#
# Soap | Candle | Resinart
#  비누 & 천연화장품
#  캔들 & 디퓨저
#  레진공예
#  석고방향제
#  비누꽃 & 드라이플라워
#  하바리움 & 무드등
# 자격증반 | 취미반 | 원데이클래스 상시 운영 중
# 기업출강. 주문제작
#   010 6783 2923
#
#
# - 인스타그램 아이디 : honggung_jewelry
# - 팔로워 수 : 241
#
#
# 단장하는 분들을 위한 특별한 핸드메이드 쥬얼리샵
# 한복&웨딩 장신구
# 원석수공예전문점
# .
# 본 사이트 ︎
# https://www.honggung.com
# .
#  레터링.파티.헬륨풍선 @in.honggung
# .
#  문의사항은 카카오톡플러스친구 ‘홍궁’ 추가!
# .
# 네이버 주문
#
#
# - 인스타그램 아이디 : keilyleeart
# - 팔로워 수 : 304
#
#
#  TIKTOK - keilylee1
#  ETSY - Keilyartstudio
#  IDUS - Sangsangart
#  Youtube
#
#
# - 인스타그램 아이디 : violett2480
# - 팔로워 수 : 305
#
#
# tel 730-2480. LeeJongMoon.Floristmeisterin. 플라워레슨 .꽃배달.난배달.화분. 디스플레이
#
#
# - 인스타그램 아이디 : manoarto_studio
# - 팔로워 수 : 259
#
#
# 한땀한땀 정성 가득담아 즐겁게 작업중
# .
# since 2015
# 정규클래스 / 원데이클래스 / 기업특강
# #안양가죽공방 #의왕가죽공방 #과천가죽공방
# #leathercraft #leatherwork #leathergoods
#
#
# - 인스타그램 아이디 : lucky.vely
# - 팔로워 수 : 2,857
#
#
# ⠀
# •구매 전 확인/안내사항 꼭 확인해주세요•
# ⠀
#  일요일 ᴏғғ / 11:00 - 20:00
#  보신 상품을 캡쳐해서 문의주세요 ෆ
#  문의   카카오채널   블리실버
#   DM,댓글 문의는 받지 않습니다
# ⠀
# ⠀
#  사이트, 문의/구매 바로가기
#
#
# - 인스타그램 아이디 : goblin_showroom
# - 팔로워 수 : 46
#
#
# 맘 가는대로...
# #댕냥이케이프#비즈공예#스팽글#헤어밴드 #핸드메이드#주문제작#뜨개질#코바늘
# 문의DM
#
#
# - 인스타그램 아이디 : theivy_2019
# - 팔로워 수 : 180
#
#
# *★국가화훼장식기능사
# ★AIFD member
# Open 10:00 - Close 21:00
# 인천시 계양구 계양대로 161.1층
# 경인교대입구역 5번 출구 앞
# 경인교대역 환승공영주차장 이용 하시면주차권 드립니다.(3분거리)
# 문의는  032 278 9255
# DM확인×
#
#
# - 인스타그램 아이디 : mylim2001
# - 팔로워 수 : 123
#
#
# '나온' 순수 우리말 처럼 모두와 함께 즐기는 창작소...
# *나온창작소*
#  리본, 마크라메, 양말목, 천연아로마, 반려견, 코일링, 입욕제 등 수업 가능
# 원데이 수업, 단체수업, 자격증, 창업반 가능~ ♡♡♡
# 주문제작~
# 궁금하심 문의주세요.
#
#
# - 인스타그램 아이디 : bebe_decoo
# - 팔로워 수 : 173
#
#
# #서른세살#5살아들맘#
# #4살딸랑구맘#연년생맘#맞팔#선팔#
# #유아동핀#핸드메이드#리본핀#주문#문의는dm #
# #
#
#
# - 인스타그램 아이디 : cozyblossom
# - 팔로워 수 : 1,045
#
#
# 이야기가 있는 꽃 정원 카페
# blooming in the garden
# flower & cafe
# 디자이너가 제안하는 플라워디자인샵
# 주문문의 카카오톡 cozyblossom
# #감성꽃집 #식물인테리어
# #호평동꽃집 #남양주꽃집
# #평내동꽃집 #플라워카페
# 호평로 60번길 7,1층
#
#
# - 인스타그램 아이디 : yeojumallcom
# - 팔로워 수 : 120
#
#
# 여주도자인 온라인 쇼핑몰
# 여주몰의 공식 인스타그램입니다.
# [1+1] 만원의 행복 상품보러가기
#
#
# - 인스타그램 아이디 : hanbasue
# - 팔로워 수 : 385
#
#
# Hand made by Su, Hanbasue(핸바수)
#  무료우편/준등기1,500/택배3,000
# (인스타에서만3만원이상구매시무료배송)
# ♡ DM 문의주세요
# *사업자 650-67-00263
#
#
# - 인스타그램 아이디 : greedacustom
# - 팔로워 수 : 15
#
#
# 주문제작 타프 사이드월 어닝 스크린 플라이 메쉬창 투명창 TPU창
#
#
# - 인스타그램 아이디 : bangmuljangsu.hun
# - 팔로워 수 : 2,109
#
#
#   핸드메이드 주문제작
#   대구광역시 중구 태평로 176-7, 106호
#   C.p 010 9105 4585
#   Kakao hide4585
#   방물장수 훈도령
# #주문제작
# #방물장수 #방물장수훈도령
# #대구실버공방 #대구은공방
# #악세사리 #은공예
# #부적주얼리 #부적
#
#
# - 인스타그램 아이디 : song_a_art
# - 팔로워 수 : 231
#
#
#  개인수업대환영  문자주세용
#  방과후.특강.자유학기제 언제나 환영합니다
#  주문제작 문자주세용
#
#
# - 인스타그램 아이디 : knit_angel_
# - 팔로워 수 : 382
#
#
# 보그니팅 코바늘*대바늘 입문반 모집중
#   창업에 관심있는 분들
#   자격증에 관심있는 분들 연락주셔요
#   보그니팅 지도원과정
#   일욜수강
# 주소;광주광역시 남구 봉선중앙로 117 (모아상가)
# Tel; (062) 671-7780
# 카톡아이디 angel926
#
#
# - 인스타그램 아이디 : song__wood
# - 팔로워 수 : 59
#
#
# 원목마그넷 수제도마 원목소품 원목가구 전문
# 문의 010.2005.5519
# 네이버-송우드검색 톡톡문의환영
#
#
# - 인스타그램 아이디 : rattan_village
# - 팔로워 수 : 67
#
#
# 라탄과 일상 이야기
# .
# .
# .
# Rattan : 라탄방앗간 @rattan_village
# Coffee : @somnium_cafe
# Candle : @somnium_candle
#
#
# - 인스타그램 아이디 : eiji_studio
# - 팔로워 수 : 860
#
#
# leather studio
# 카카오톡: eeeiji1200
# 수업중에는 통화가 어렵습니다
# 카톡으로 연락주시면 수업이 끝나고 답변 드리겠습니다
#
#
# - 인스타그램 아이디 : sunota_embroidery
# - 팔로워 수 : 21,819
#
#
# Copyright ⓒ SUNOTA. All Rights Reserved
# -
#  ️프랑스자수, 코바늘 클래스
# • 일산 화요일, 목요일 그리고 토요일
# • 강남 토요일
#  ️온라인 (자수,코바늘) 클래스
#  ️자수 diy kit
# -
# 수노타 일상 계정 @sunota_is
#
#
# - 인스타그램 아이디 : honggung_jewelry
# - 팔로워 수 : 241
#
#
# 단장하는 분들을 위한 특별한 핸드메이드 쥬얼리샵
# 한복&웨딩 장신구
# 원석수공예전문점
# .
# 본 사이트 ︎
# https://www.honggung.com
# .
#  레터링.파티.헬륨풍선 @in.honggung
# .
#  문의사항은 카카오톡플러스친구 ‘홍궁’ 추가!
# .
# 네이버 주문
#
#
# - 인스타그램 아이디 : keilyartstudio
# - 팔로워 수 : 1
#
#
# Or little creativity place
#
# For more info
#
#
# - 인스타그램 아이디 : lee_umin
# - 팔로워 수 : 413
#
#
# Handmade Jewelry, Korea. 핸드메이드 주얼리 디자이너.
# 구매문의는 DM 또는 카톡ID: kittyani 으로 연락주세요.
#
#
# - 인스타그램 아이디 : witty_.flower
# - 팔로워 수 : 46
#
#
# -위티 플라워 @witty_.flower
# -꽃 관련 문의시 dm 부탁드립니다
# -사진사용시 출처를 꼭!남겨주세요
# •••••••••••
# 예쁜 꽃을 닮았으면 하는 마음으로••
# •••••••••••
#  스토어팜
#
#
# - 인스타그램 아이디 : lebeton_concrete_studio
# - 팔로워 수 : 76
#
#
# 르베톤
# 르베톤 콘크리트
# 견적 및 상담문의
# 대표번호 1522-3857
# lebeton@naver.com
# m.blog.naver.com/lebeton
#
#
# - 인스타그램 아이디 : chick_couple_wedding
# - 팔로워 수 : 153
#
#
# 다이렉트 결혼준비 과정 계정입니다! @direct.wedding 결혼준비 함께해요
#  추천인 코드: “예신작꼬꼬”
#
#
#
# - 인스타그램 아이디 : designstring
# - 팔로워 수 : 55
#
#
# 주문제작 사원증목걸이 전문업체
# 친절한상담:D 퀄리티 있는 디자인
# 고객센터 070-8802-7683
# 카카오톡 @디자인스트링
#
#
# - 인스타그램 아이디 : studio_ilyoil
# - 팔로워 수 : 413
#
#
# Jewelry Design Studio
# • 구매 및 클래스 문의 DM으로 연락주세요.
# 커리큘럼은 블로그 내 확인 가능합니다.
# • 일, 월 정기 휴무
# • 아몬즈 • 아이디어스 입점
# ✧ art work  @iam.mj
#
#
# - 인스타그램 아이디 : doore_caligrafia
# - 팔로워 수 : 1,120
#
#
# 두레, 阧鶆
# 전각, 수제도장, 캘리그라피
#  전각,인장 --> @doore_seal 두레새김
#  작품 주문 • 문의 ...DM 또는 카톡
#
# #두레새김#전각#수제도장#篆刻#印章
# #doore_seal#engraver
# #두레글씨#캘리그라피#멋진먹글씨
# #calligraphy
#
#
# - 인스타그램 아이디 : bbbig05
# - 팔로워 수 : 15
#
#
# 𝑹𝒆𝒔𝒊𝒏𝒂𝒓𝒕⚘ #레진아트 #레진공예 #하트쉐이커
# ↓제품사진 및 상세안내는 링크를 확인해주세요
#
#
# - 인스타그램 아이디 : yeo_eunju83
# - 팔로워 수 : 8,694
#
#
# 🅢🅞🅞 🅨🅔🅞🅝
# 항상행복한일만,좋은일만 가득하길
# #육아소통환영 #뷰티체험단환영 #선팔하면맞팔가요
# #맞팔환영 #맞팔 #인친해요
# #맞팔해요 #칼맞팔 #선팔하면바로맞팔가요
#
#
# - 인스타그램 아이디 : sea_neul
# - 팔로워 수 : 1,871
#
#
# 교림공방
# 교림매니저_새늘
# 모스틀계정 @scandiamossteul
# 스칸디아모스 ,프리저브드플라워
# 010-4875-7087
# 문의는 여기로 해주세요
#
#
#
# - 인스타그램 아이디 : veravera_tarot
# - 팔로워 수 : 220
#
#
#   타로 "찐"소통 환영
#   파워 에너지 충전
#   따뜻한 마음 전달
#   전쟁속에서 살아남기
#  주문제작 (DM, 오픈마켓 가능)
#
#
#
# - 인스타그램 아이디 : evighet_leather
# - 팔로워 수 : 10,322
#
#
# Leather craft Brand
# 특별한날 특별한분께 특별한선물을
# 제품, 클래스 (정규, 원 데이) 문의
# 상담은 하단에 오픈 채팅방을 이용해주세요.
#
#
# - 인스타그램 아이디 : y.nail__9
# - 팔로워 수 : 9
#
#
#  수제 네일
#  구성품-알콜스왑,우드스틱,네일글루
#  주문양식:인스타 하이라이트
#  반택(cu)1600, 택배 3500
#  편하게 디엠해주세용
#
#
# - 인스타그램 아이디 : pilates_jenny_
# - 팔로워 수 : 5,357
#
#
# 선팔 = 맞팔, 좋아요정
# 늦어도 답방 꼭 가요
# #선팔 #맞팔 #좋아요반사   언팔은 즉시 언팔
#
#
# - 인스타그램 아이디 : yangsanpulip
# - 팔로워 수 : 569
#
#
# #양산미싱 #양산홈패션 #양산공방 #증산공방
# 양산시 #물금읍 증산역로 149 세영프라자 (하나은행 4층)
# 수강문의 : 010-9392-2362
#
#
# - 인스타그램 아이디 : goribyruga
# - 팔로워 수 : 70,413
#
#
#  ️2021년 5년연속 브랜드파워대상
#  ️2018년 소비자선호브랜드대상
#  ️2017년 가치경영대상
#  ️Jewelry디자인학 박사학위
#  ️보석감정사
#  ️쇼룸방문예약 070-7607-0607
#
#
# - 인스타그램 아이디 : lovejieuny
# - 팔로워 수 : 344
#
#
# 물금역 앞 캘리그라피 공방입니다
# #캘리그라피
# (캘리그라피, 수채화캘리, 수묵일러스트, 전각)
# -부산대학교평생교육원 출강
# -양산시청여성복지센터 출강
# 드로잉계정 @jieuny_drawing
# 작업실- 양산 물금읍 버들길 29-13 1f
# 수강문의- 010 2124 3752
#
#
# - 인스타그램 아이디 : wood_aout
# - 팔로워 수 : 220
#
#
# ⠀
# 감성캠핑 목공방 Aout[우트]
# 우드 캠핑용품, 도마 및 소품 주문 제작
# 제작 제품 사진은 @wood_aout_studio
# ⠀
# 주문제작 문의는 카카오톡 채널 ID : wood_aout 또는 인스타그램 DM 부탁드립니다.
# 구매는 하단 링크에서 확인 해주세요.
#
#
# - 인스타그램 아이디 : moo.byul
# - 팔로워 수 : 343
#
#
# 여행지의 기억을 담은 작고 귀여운 것들을
# 작가 부부가 직접 기획하고 제작합니다.
# ⠀
# 납품 문의와 구매 문의는
# 카톡플러스친구 ‘무궁화별’ 추가ఇ
# 디엠   빠른답변
#
#
# - 인스타그램 아이디 : do_kim54
# - 팔로워 수 : 205
#
#
#
#
# - 인스타그램 아이디 : douceur_ann
# - 팔로워 수 : 66
#
#
#  Pastry cook ᴍᴀᴄᴀʀᴏɴ•ᴅᴀᴄǫᴜɪᴏsᴇ•ᴛᴀʀᴛ•ᴄᴀᴋᴇ•ᴄᴀɴᴇʟé
#   ɴɪᴀɢᴀʀᴀ ᴏɴᴛᴀʀɪᴏ
#
#
# - 인스타그램 아이디 : uenara_wood
# - 팔로워 수 : 789
#
#
# #유의나라우드스튜디오
# •분당구 수내동
# •도마 원데이클래스/취미목공반 및 학교 체험교육
# •주문제작 및 구매문의 | 카카오채널 유의나라 (인스타DM )
# •휴무안내: 매주 일요일•월요일 휴무
#  제품 구매 시
#
#
# - 인스타그램 아이디 : delpino_hands
# - 팔로워 수 : 340
#
#
# 핸드메이드 내츄럴 짙은 감성
# 매일매일 손에 잡히는
# 핸드메이드 패브릭
# 델피노핸즈
#
#
# - 인스타그램 아이디 : keilyartstudio
# - 팔로워 수 : 1
#
#
# Or little creativity place
#
# For more info
#
#
# - 인스타그램 아이디 : smartmoja_official
# - 팔로워 수 : 15,472
#
#
# 스냅백 볼캡 모자제작, 마스크캡 디자인특허 스마트모자입니다
# 커플 가족 동호회 팬클럽 프렌차이즈 모자!
# 1개부터 단체모자까지 고퀄리티 맞춤제작!
# 직통제작문의 : 010-3854-7256
# 카톡 아이디 : smoja
# 대표전화 : 1661-7256
# 스마트모자 홈페이지는
#
#
# - 인스타그램 아이디 : 7815skok
# - 팔로워 수 : 14
#
#
#
#
# - 인스타그램 아이디 : springnr_
# - 팔로워 수 : 1
#
#
#
#
# - 인스타그램 아이디 : bravomade_official
# - 팔로워 수 : 10
#
#
# -
# craft & limited
#
#
# - 인스타그램 아이디 : soboon_product
# - 팔로워 수 : 2,649
#
#
# “작은가치를 만들어 나눈다”
# 소품을 제작하는 소분제작소 입니다
# .
# .
# Life style product
# .
# 블로그 : 소분제작소
# 아이디어스 : 소분제작소
# 네이버스토어 : 소분제작소
#
#
# - 인스타그램 아이디 : yunri.i
# - 팔로워 수 : 132
#
#
# 맘에 드신 분, 원하는 문구나 디자인 있으시면 디엠주세요.
# 최대한 고객님 뜻을 존중하겠습니다.
# 핸드메이드라서 동일한 제품이라도 똑같지는 않습니다.
# 또한 작은 기포가 있을수 있으니 양해바랍니다.
#
#
# - 인스타그램 아이디 : norann_on
# - 팔로워 수 : 103
#
#
# ღ
#  ︎ 사진이 들어간 키링/그립톡 주문제작ღ
#  ︎ 탱탱한 재접착 젤글루 그립톡 ღ
#  ︎ 최애 사진을 하트안에 넣어보아요 ღ
# 워터쉐이커는 반짝반짝  찰랑찰랑  예뻐요
# #통신판매업신고 완료
#   모든 문의는 오픈카톡으로 ღ
#  스마트 스토어 놀러오새오 ღ
#
#
# - 인스타그램 아이디 : su.sue.now
# - 팔로워 수 : 57
#
#
# 여성복디자이너가 만드는 인형과의 커플룩~인형옷 그대로 여성복 주문제작.옷을 만드는 테크닉 개인레슨~키큰Su와 키작은Sue의~인형들과 함께 옷만드는 이야기~DM문의주세요
# ->@sucouture1203 (입체패턴/평면패턴/개인레슨)
#
#
# - 인스타그램 아이디 : y.nail__9
# - 팔로워 수 : 9
#
#
#  수제 네일
#  구성품-알콜스왑,우드스틱,네일글루
#  주문양식:인스타 하이라이트
#  반택(cu)1600, 택배 3500
#  편하게 디엠해주세용
#
#
# - 인스타그램 아이디 : marquage.r
# - 팔로워 수 : 1,680
#
#
#  marquage.r (마카쥬랑)
#  반스커스텀, 1:1 맞춤 주문제작!!
#  생일선물, 기념일선물, 선물템
#  김해 마카쥬 ️가방,의류 토탈샵 ️
#  문의는 DM
#   주일은 휴무입니다
#
#
# - 인스타그램 아이디 : art_caron
# - 팔로워 수 : 708
#
#
# 𝕒 𝕣 𝕥 𝕔 𝕒 𝕣 𝕠 𝕟 수제 디저트 cafe
# |OPEN 12시 - 8시 | 정기휴무 일요일 | DM ️ | 주차 ️ | 애견동반 ️ |  031-8016-8016 | 카카오pay ️ 네이버pay ️ |
#
#
# - 인스타그램 아이디 : value_jjjinn
# - 팔로워 수 : 605
#
#
# #신발커스텀 #커스텀신발 #밸류커스텀 #명품신발커스텀
#    신발에 새 가치를 불어넣는 사람
#     밸류 커스텀 Value Custom
#      커스텀 문의는 카톡 부탁드려요
# ⠀
#
#
# - 인스타그램 아이디 : neulsom9336
# - 팔로워 수 : 273
#
#
# 들러주셔서 감사합니다^^
# 전주 늘솜 인형 공방
# 인형옷 주문제작. 인형옷diy.리페인팅
# 문화누리카드가맹점/ 늘솜인형공방 스토어팜/
# 010 2468 9336
#
#
# - 인스타그램 아이디 : baejs3868
# - 팔로워 수 : 709
#
#
#
#
# - 인스타그램 아이디 : frfr_official
# - 팔로워 수 : 288
#
#
#  프랑프렌 frfr
# 제품가격 / 주문제작 / 원데이클래스 문의
#
#
# - 인스타그램 아이디 : malang_gongan
# - 팔로워 수 : 11
#
#
#   소중한 나의 반려동물 그림을 선물합니다(무료 x)
#   문의는 오픈카톡링크 또는 DM 주세요
# -
# #반려동물일러스트#반려견드로잉#반려묘드로잉#반려견일러스트#반려묘일러스트#그림스타램#일러스트#라인드로잉#커플드로잉#말랑공간
#
#
# - 인스타그램 아이디 : j_woodlab
# - 팔로워 수 : 193
#
#
# Crafted by Jason Kang(@kangjeongwoong)
# 우리 몸에 편안함을 주는 디자인 추구♡&♡
# - #Woodwork
# - #Woodcrafts
# - #목공예 #우드카빙 #핸드메이드
# - #주방소품 #보석함 #시계케이스
# - DM문의 환영♡
#
#
# - 인스타그램 아이디 : euna_embroidery
# - 팔로워 수 : 319
#
#
# 카페&공방 @cafe_oneul.haru 오늘,하루.
# 인천시 부평구 주부토로 151번길 31
# 부평구청역 3번출구
# -
# 프랑스자수 수업, 주문제작
# 뜨개, 패브릭 소품, 패브릭 인형 주문제작
# ( 문의 DM . 카톡ID : eunasoul )
#
#
# - 인스타그램 아이디 : drawing_myday
# - 팔로워 수 : 0
#
#
# 문의 및 주문은 하이라이트 확인 후에 dm주세요 ♡︎ !
# _
# #라인드로잉 #주문제작 #그림 #그림문의 #일러스트
#
#
# - 인스타그램 아이디 : cafe_oneul.haru
# - 팔로워 수 : 303
#
#
# 부평구청역, 굴포천역
# 부평구 주부토로 151번길 31
# 공방 그리고 카페
# ( 프랑스자수 수업, 뜨개상품 판매, 공간대여 문의 DM )
# @oneulharu_yoon @euna_embroidery
#
#
# - 인스타그램 아이디 : soap_by_ej
# - 팔로워 수 : 218
#
#
#   natural/palm free/vegan
#   Australia wide shipping
#   DM for order
#  비누문의 DM주세요. 호주/멜번입니다.
#
#
# - 인스타그램 아이디 : noble.j_hi
# - 팔로워 수 : 1,184
#
#
#  문의는 DM, 카톡 in7721
# 댓글문의X 누락되기쉬워요
# 𝟷𝟺𝙺, 𝟷𝟾𝙺 𝙶𝙾𝙻𝙳 &̴ 𝙳𝚒𝚊𝚖𝚘𝚗𝚍
# ➢ 𝙷𝚊𝚗𝚍𝚖𝚊𝚍𝚎
# °𝙾𝙿𝙴𝙽 𝟷𝟷 : 𝟶𝟶
# °𝙲𝙻𝙾𝚂𝙴 𝟷𝟿 : 𝟶𝟶
# ㆍ
# 매월 둘째, 넷째 수요일 정기휴무입니다
#
#
# - 인스타그램 아이디 : tiger._.ss
# - 팔로워 수 : 5,084
#
#
#  class : 천연비누, 천연화장품, 입욕제(버블바, 바스붐)
#  창업반, 취미반, 원데이클래스, 주문제작
#  예약 / 수업 문의 010.4922.0458
#  대구 달서구 월서로 31 상가 1동 2층  상인홈플러스 뒤편
#
#
# - 인스타그램 아이디 : lovable_goods
# - 팔로워 수 : 0
#
#
# Hello DM or OPEN CHAT
#
#
# - 인스타그램 아이디 : lovable_goods
# - 팔로워 수 : 0
#
#
# Hello DM or OPEN CHAT
#
#
# - 인스타그램 아이디 : _usual.h
# - 팔로워 수 : 157
#
#
# 디자이너 주얼리 브랜드
# • 14K Gold & Silver 925, 자체제작
# • Simple & Classic & Value
# • 문의 >카톡플친 유주얼에이치,홈페이지 Q&A 게시판
#
#
# - 인스타그램 아이디 : rookie.sh
# - 팔로워 수 : 328
#
#
# ʀᴏᴏᴋɪᴇ's ᴅɪᴀʀʏ ☻
#  2017.8.3 ғ
#  #나는루키 #루키비디오 #루키동반
#
#
# - 인스타그램 아이디 : haus_der_rose
# - 팔로워 수 : 393
#
#
# 100% 수제 도자기 ♡
# [디자인등록 중 ]
# 제작 기간은 평균 한달정도 소요됩니다.
# 별도 주문제작은 상담 후 가능합니다.
#
#
# - 인스타그램 아이디 : cafe_921214
# - 팔로워 수 : 180
#
#
#  카페 스탬프 전문 연구소 입니다.
# 직접 카페를 운영 & 실용적 사용 연구
# （╹◡╹）♡
#  1:1 맞춤제작
#  사장님이 만족하실때까지 디자인 시안 컨펌 후 제작합니다.
#  주문시 확인즉시 연락드려요~!
#  감성카페 스탬프 주문하기
#
#
# - 인스타그램 아이디 : nono_chwihyang
# - 팔로워 수 : 106
#
#
# 핸드메이드
#
#
# - 인스타그램 아이디 : springnr_
# - 팔로워 수 : 1
#
#
#
#
# - 인스타그램 아이디 : oddblanc
# - 팔로워 수 : 12,133
#
#
#  SHOP
#  Online 홈페이지, 무신사, IDUS, KAKAO, ETSY, Amazon
#  Offline 서울 마포 서교동 380-10 (예약제)
#  Contact
#   oddblanc@gmail.com
#
#
# - 인스타그램 아이디 : blacktan_leather
# - 팔로워 수 : 10,147
#
#
#  3.1운동 및 대한민국 임시정부 수립 100주년 기념 사업 선정
# (작품 주문 및 상담은 아래 링크의 카톡!) DM ok  카드결제 ok
# 언제든 편하게 문의주세요
#
#
# - 인스타그램 아이디 : hongwhieun
# - 팔로워 수 : 311
#
#
# *섬유그림작가
# *전통의 멋을 현대의 감성으로 표현하고 싶은, 섬유그림과 천연염색을 이용하여 생활한복-홈인테리어 소품제작
#
# #맞춤제작
# #섬유공예
# #천연염색
# #생활한복#소품제작
# #섬유그림#원데이클래스
# #단하나뿐인디자인
#
#
# - 인스타그램 아이디 : pandora.kr_
# - 팔로워 수 : 498
#
#
# 고객에 맞게 맞춤제작해드리는 판도라피아
#  02)744-5200, 010-7227-8099
# 실시간 카톡상담가능
# 카톡ID,etsy:pandorapia
#  굿즈 뱃지 디자인 포트폴리오
# @logomark.kr/@13dog11cat
# 유튜브 bit.ly/2WLXuB1
#
#
# - 인스타그램 아이디 : blessgarden13
# - 팔로워 수 : 999
#
#
# 당신의 식탁이 아름다워지는 곳
# 그릇 주문제작/ 그릇판매
#
#
# - 인스타그램 아이디 : cachet_leather
# - 팔로워 수 : 1,377
#
#
# 가죽공방 CaChet
# _
# LEATHER CRAFT
# CUSTOM MADE
# HAND MADE FASHION ITEM
# _
# KAKAO @madamp
# _
#
#
# - 인스타그램 아이디 : hweeni_0909
# - 팔로워 수 : 127
#
#
# - 소품 주문제작 및 판매
# - 홈패션 기초반, 취미반
# - 코바늘 소품수업
# - 원데이클래스, 태교반, DIY
# 문의는 DM 또는 카톡  (디엠은 확인이 느려요)
#
#
# - 인스타그램 아이디 : sol_assic
# - 팔로워 수 : 444
#
#
# 𝙝𝙖𝙣𝙙 𝙢𝙖𝙙𝙚 𝙡𝙚𝙖𝙩𝙝𝙚𝙧 𝙜𝙤𝙤𝙙𝙨 '𝙨𝙤𝙡𝙖𝙨𝙨𝙞𝙘'
#
#
# - 인스타그램 아이디 : yeojumallcom
# - 팔로워 수 : 120
#
#
# 여주도자인 온라인 쇼핑몰
# 여주몰의 공식 인스타그램입니다.
# [1+1] 만원의 행복 상품보러가기
#
#
# - 인스타그램 아이디 : corolaflower
# - 팔로워 수 : 2,009
#
#
# 꽃다발꽃바구니예약판매,화분선물판매,플라워클래스
# -
#  화훼장식기사,기능사/조경기능사
#  보존화자격1급/압화체험강사/동양꽃꽂이사범1급~초급
#  독일국가공인플로리스트마이스터
# -
#   플라워클래스 상시모집중
#  031.526.7922
#  클래스•꽃상품주문예약문의
#
#
# - 인스타그램 아이디 : clay_ssam
# - 팔로워 수 : 110
#
#
# #클레이 #클레이꽃 #클레이인형 #캐릭터
# #클레이수강 #클레이공방 #안산클레이체험
# 취미&자격증반/수강•출장/주문제작 DM으로 문의 주세요 ◡̈
# 안산시 상록구 반석로 54 신안프라자 163호
# 김명숙
# 문의 031 418 4538
#
#
# - 인스타그램 아이디 : kook_dae_
# - 팔로워 수 : 59
#
#
#  국대공방
# 100 % 핸드메이드 나무공방
# 반려동물 하우스 및 용품 제작
#
#
# - 인스타그램 아이디 : catherine_leather_craft
# - 팔로워 수 : 798
#
#
# 캐서린 가죽공방입니다~^^
# 당신만을 위한 특별한 선물을 제작해 드립니다.
# ♡주문제작♡
# ♡일일체험수업♡
# ♡단품수업♡
# ♡정규수업♡
# ♡출강수업♡
# *Tel : 010. 5062. 7556
# *Facebook, Kakaotalk, Kakaostory ID : hlove517
#
#
# - 인스타그램 아이디 : gunpo_ricecake
# - 팔로워 수 : 67
#
#
# #떡집#군포떡집#산본떡집#안양떡집#범계떡집#경기도떡집#기름집#국산참기름#참기름#들기름#꿀떡#찰떡#백설기#떡볶이떡#가래떡#송편#결혼이바지#이바지떡#답례떡#결혼답례떡#개업떡#돌떡#떡케이크#떡집추천#군포맛집#산본맛집#안양맛집#떡배달#범계맛집#산본맛집추천#주문떡#군포맛집추천
#
#
# - 인스타그램 아이디 : i_light.11
# - 팔로워 수 : 3
#
#
# LED 경관조명 LED모듈 LED네온사인(실리콘)
# #LED네온사인주문제작 #LED네온아트
# #인테리어 #캠핑조명
# 제주도 및 해외배송가능
# 상담 오전9 - 오후6
# 052 915 5551 010 4857 6750
#
#
# - 인스타그램 아이디 : 7816skok
# - 팔로워 수 : 20
#
#
#
#
# - 인스타그램 아이디 : iow_studio
# - 팔로워 수 : 95
#
#
# iow studio
# In other world
# “Imagination can unfold into reality.”
# 구월동 1235-2 1층
# 100%예약제 가죽공방
# 주문제작 및 클래스 문의 dm주세요
# Tel: 01057591372
#
#
# - 인스타그램 아이디 : joozaro
# - 팔로워 수 : 84
#
#
# CUSTOM-MADE LEATHER OBJET
# 특수피혁 제품 제작 및 수선 (쇼룸 예약방문)
# ■ casual collection @joozaro.446
#
#
# - 인스타그램 아이디 : hanabi._
# - 팔로워 수 : 700
#
#
# 하나비 시즌2  ️
# 성북구 삼선교로 20 2층
#   12:00-23:00
#
#
# - 인스타그램 아이디 : bliss_jewelleryshop
# - 팔로워 수 : 112
#
#
#  핸드메이드 악세사리
#  써지컬 스틸 전문
# #jewellery #surgicalsteel #ring #earings #necklace #bracelet #accessories #악세사리 #써지컬스틸 #팔찌 #발찌 #목걸이 #반지
#  DM문의✩‧₊˚ ﾟ☾ ｡⋆ ✩‧₊˚
#
#
# - 인스타그램 아이디 : locust_leather
# - 팔로워 수 : 151
#
#
# ♡찾아오시는길
# 전남 담양군.읍 객사2길 11-23 (구 담양메뚜기)
# ♡로커스트오픈
# 화요일 휴무
# #가죽공예#가죽공방#가죽공예원데이클래스#일일체험#담양가죽공예#담양공방#담양일일체험카페#공방카페#공방카페로커스트#로커스트가죽공방#체험#담양공방카페#담양가죽공방#직장인취미
#
#
# - 인스타그램 아이디 : borisewing1004
# - 팔로워 수 : 51
#
#
#
#
# - 인스타그램 아이디 : cafe_hooamdong
# - 팔로워 수 : 1,072
#
#
#  홈메이드방식으로 만드는 메뉴들~ 정성과 재료를 아끼지 않고 집에서 먹는것처럼 건강하게 만들어요~ 더치커피,핸드드립전문점,원두판매 .
# 로스팅랩실:핸드드립 교육.커피세미나.강의. 대관.(소모임)
# OPEN 09:00 CLOSED 23:00
# TEL :010-2251-8232
#
#
# - 인스타그램 아이디 : cafe.miqreh
# - 팔로워 수 : 273
#
#
# 주문문의 : 카카오톡 ID : 카페미크레
# 수원시 권선구 동수원로 36번길 9
# #cafe_miqreh #미크레
# #수원수제케이크 #아이싱쿠키주문 #메세지쿠키 #캐릭터쿠키제작 #레터링케이크 #주문케이크 #수제쿠키 #답례품 #행사쿠키제작
#
#
# - 인스타그램 아이디 : luco_and_love
# - 팔로워 수 : 10,452
#
#
# 쥬얼리 주문/제작 문의 DM or KAKAOTALK 카드결제가능
# worldwide shipping contact dm  paypal
# kakao id : soyoungieee
# 타투계정 @luco_and_tattoo
# 일상 @blueinthewinter
#
#
# - 인스타그램 아이디 : choikj0509
# - 팔로워 수 : 12
#
#
#  바느질하는 할머니
#
#
# - 인스타그램 아이디 : faire_store2021
# - 팔로워 수 : 11
#
#
# 한땀한땀 정성과 사랑으로 꽃피우다
# 토탈 수공예품 스마트스토어를 준비하고 있어요
#
#
# - 인스타그램 아이디 : openupthelamp
# - 팔로워 수 : 152
#
#
#  스토어팜/텐바이텐/아이디어스 입점
#
#
# - 인스타그램 아이디 : 7816skok
# - 팔로워 수 : 20
#
#
#
#
# - 인스타그램 아이디 : tmong_official
# - 팔로워 수 : 32
#
#
# 하이퀄리티 단체티는 티몽!
# 티몽에서 모두 같이입자!  카톡아이디 tmong
# #끄라몽 에서 운영하는 티몽! 믿고 문의 주세욤  1566-6417
#
#
# - 인스타그램 아이디 : woodworks_been
# - 팔로워 수 : 719
#
#
#  창원 DIY 목공방
#  원목가구 주문제작
#  목재CNC가공 , 레이저각인
#  목공DIY 수강생모집 , 원데이클래스
#   010-9305-3551
#  카톡 ▷ @비니네나무
# #창원목공방 #목재CNC가공 #레이저각인 #원데이클래스
#
#
# - 인스타그램 아이디 : lily_hands_
# - 팔로워 수 : 2,212
#
#
# #담배케이스 #데코덴 #레진케이스
#  24시간 상담문의
#  아이디어스 : 릴리핸즈
#  네이버스토어팜 : 릴리핸즈
#  인스타구입시 5만원이상 무료배송
# 카톡 : sphj1004
#  디자인도용금지
#
#
# - 인스타그램 아이디 : flowershop_grandbleu
# - 팔로워 수 : 38
#
#
# 그랑블플라워 인천 연수구 동춘동 예쁜 꽃집입니다 인천,서울,경기지역 배송가능합니다. 영업시간 오전10시부터 오후9시 010-6775-5856
#
#
# - 인스타그램 아이디 : j_luxleather
# - 팔로워 수 : 81
#
#
# LEATHER ATELIER
# HANDMADE LEATHER PRODUCTS / J_LUX CLASS
# 주문 제작 / 가죽공예 수업
# -
# KAKAO : JLUXLEATHER / 01032409214
# **DM보다는 카카오톡 연락이 빠릅니다
# 서울특별시 강북구 노해로 7길 10
#
#
# - 인스타그램 아이디 : ashu_s_making
# - 팔로워 수 : 36
#
#
#  ️굿즈주문제작 / 일러스트 굿즈 / 캐릭터굿즈
#  ️특별하고 귀여운 걸 만들어보자
#  그리고, 만듭니다
#  SHOP 및 문의사항
#
#
# - 인스타그램 아이디 : suan_j_
# - 팔로워 수 : 209
#
#
# 내공주 사랑해
#
#
# - 인스타그램 아이디 : ellymaker_shop
# - 팔로워 수 : 86
#
#
# 엘리메이커 핸드메이드 주문제작
# *아크릴 도장 (비누도장, 도예도장)
# *스크래퍼 주문제작 *가죽소품 주문제작
# @ellymaker @ystudio_soap 도장참고
# Kakao_loveboss1 /디엠 환영
#
#
# - 인스타그램 아이디 : marronnier_flower_studio
# - 팔로워 수 : 511
#
#
# 꽃다발, 꽃바구니, 꽃박스, 리스, 갈란드 주문제작/원데이클래스, 키즈클래스 상시모집/드라이플라워, 다양한 식물
# Address: 종로구 창경궁로 281
#
#
# - 인스타그램 아이디 : bennybenni_
# - 팔로워 수 : 747
#
#
# 𝐉𝐞𝐰𝐞𝐥𝐞𝐫
# 𝐉𝐞𝐰𝐞𝐥𝐫𝐲 𝐂𝐫𝐞𝐚𝐭𝐞𝐫
# 𝗟𝗶𝘃𝗶𝗻𝗴 𝘄𝗶𝘁𝗵 𝘁𝗵𝗲 𝟯 𝗖𝗮𝘁𝘀
# 뭐든지 다 만드는 언니
#
#
# - 인스타그램 아이디 : bangaun_nail
# - 팔로워 수 : 650
#
#
#  충남 당진시 계성2길 68 1층 모든날모든순간 내 반가운네일  예약상담은 아래 링크주소 참고(DM문의 )
# ⠀
#  활동이력: 캣츠크루 4기, 네일파츠대장 1기, 젤로젤로 1기
#
#
# - 인스타그램 아이디 : casa_factory
# - 팔로워 수 : 744
#
#
# 훌륭한 소재와 합리적인 가격
# 일상에 빛이 되는 곳, 까사팩토리
# _
# •9시~18시 (평일, 주말 연중뮤휴)
# •고객센터 031-949-0897
# •경기도 파주시 탄현면 헤이리마을 93-53
# ⠀
# #클린까사 #뭉스슬립 #파나리아
# #패브릭소파 #호텔식침대 #이태리세라믹식탁
#
#
# - 인스타그램 아이디 : bonitt__
# - 팔로워 수 : 313
#
#
# ❁니트로 아름다움을 만들다❁
# 핸드메이드 비싸다는 편견 버려주세요,  ︎
# 모든 제품 컬러커스텀 가능합니다
# ⠀
# 일상ო @__eunseo_mom_
#  ︎모든 주문은 DM, 오픈채팅  ︎
#
#
# - 인스타그램 아이디 : with.darwin
# - 팔로워 수 : 45
#
#
# 로고ㅣ명함ㅣ인쇄물ㅣ자체제작ㅣ맞춤제작 디자인
# ⓒWITHDARWIN All rights reserved.
# ⠀
# • 문의는 DM 및 하단링크 [ 스토어팜 & 카카오톡 ]
#
#
# - 인스타그램 아이디 : tinkerbell_jewelry
# - 팔로워 수 : 63
#
#
#  디자인+아이디어 도용시 법적 책임을 물을 수 있습니다.
# 구매&주문제작 - DM 주세요 :)
# ⠀
#  보석귀금속 전공
#  보석감정사 / MV 자격증 보유
#  세공과 다양한 작업도 함께할 예정입니다.
# ⠀
#  아이디어스&네이버 스토어 입점
#
#
# - 인스타그램 아이디 : flower_eum
# - 팔로워 수 : 398
#
#
# 경상북도 경산시 중방로57(중방동)
# 문의 : 010-2331-2021
# #경산꽃집 #중방동꽃집 #경산꽃배달
# 월~금: 9시-19시, 토:12시-18시, 일•공휴일은 휴무입니다
# 전화예약주문 ️ 경산배달 ️ 주문예약 ️
#
#
# - 인스타그램 아이디 : jiscakeboutique
# - 팔로워 수 : 549
#
#
# •Professor@LBCC
# •Pastry Chef@Ritz Carlton,Fourseasons, Roosevelt Hotel
# *Customized Cakes,Cupcakes in OC, LA
# *Licensed *Insured *Business Permit
#
#
# - 인스타그램 아이디 : da__kkom
# - 팔로워 수 : 130
#
#
# <마크라메와 그린테리어>
# 좋은 사람들과 인연을 함께 묶어가는 다,꼼
# 다,풀 @da__pul
# 일상 @diary.twone
#
#
# - 인스타그램 아이디 : with.darwin
# - 팔로워 수 : 45
#
#
# 로고ㅣ명함ㅣ인쇄물ㅣ자체제작ㅣ맞춤제작 디자인
# ⓒWITHDARWIN All rights reserved.
# ⠀
# • 문의는 DM 및 하단링크 [ 스토어팜 & 카카오톡 ]
#
#
# - 인스타그램 아이디 : ra_on_cafe
# - 팔로워 수 : 217
#
#
# 구월동 성말로32번길6-1
# 라온
# 휴무 : 인스타 공지
# 외부음식 반입금지
# 기념일 꽃다발 , 선물용 꽃 바구니 제작문의 : DM
# 대관문의  : DM
# 카페 내부 촬영은 가능하나
# 쇼핑몰 혹은 업체 분들은
# 대관 문의 부탁 드립니다 :)
#
#
# - 인스타그램 아이디 : bestdayever____
# - 팔로워 수 : 453
#
#
# 최고의 하루와 함께하는 나만의 토퍼
#
# 여유있게 주문해주세요
# (주문 -> 도착까지 3~4일 소요)
#
# DM 보단 카카오톡 문의가 답변이 빠릅니다
# (카톡상단돋보기누르기 -> bestdayever 친구추가 )
#
# 가격은 스마트스토어에서 확인 가능합니다
#
#
# - 인스타그램 아이디 : neulbyhan
# - 팔로워 수 : 412
#
#
# 전통을 모티브로 바느질하는 공방&카페
# 한복&전통소품 제작
#   경기도 평택시 조개터로42번길 30-14 1층
#   031-658-0331
#   영업시간
# 화-금 오전 10시30분~오후 7시
# 토 오전 10시30분~오후 5시
# 일•월•공휴일 휴무
#
#
# - 인스타그램 아이디 : s.eunji7799
# - 팔로워 수 : 422
#
#
#
#
# - 인스타그램 아이디 : leblic_atelier
# - 팔로워 수 : 4,706
#
#
# 평생 즐기는 가죽공예
# - 패턴반, 취미반, 원데이클래스 운영
# - 1:1 맞춤수업
# 주문제작
#
#
# - 인스타그램 아이디 : cakeimade_
# - 팔로워 수 : 8,737
#
#
# CAKE I MADE
# (DM  확인 어렵습니다)
# 서울 NO.1 케익만들기 체험/주문제작
# "케익아이메이드" 대학로점 (혜화역3번출구)
# ●월-일 11:00~20:00 연중무휴
# ●Since 2011~ 10년차 딸기 케익전문
# ●카카오톡플러스친구 : 대학로 케익아이메이드
#
#
# - 인스타그램 아이디 : leather_bin
# - 팔로워 수 : 1,042
#
#
# 010.3596.6433.
# Kakao : leatherbin/레더빈
# 가죽공예수업 / 주문제작 / 키케이스제작.
# leather goods maker.
#
#
# - 인스타그램 아이디 : supia_drawing
# - 팔로워 수 : 90
#
#
# 아름다운 추억을 그려 드려요
#   1:1일 맞춤 그림&굿즈 제작
#   상시 주문 가능합니다.
#   아이디어스 찾아주세용
#
#
# - 인스타그램 아이디 : sky7272x
# - 팔로워 수 : 1,627
#
#
# 도자기핸드페인트 주문제작(최소2주 소요)~판매/선물용 문의주세요 ~접시 머그컵 제작 ~빨강머리앤 머그 주문제작
#
#
# - 인스타그램 아이디 : garden.interior
# - 팔로워 수 : 13
#
#
# woongjupark
#
#
# - 인스타그램 아이디 : bestdayever____
# - 팔로워 수 : 453
#
#
# 최고의 하루와 함께하는 나만의 토퍼
#
# 여유있게 주문해주세요
# (주문 -> 도착까지 3~4일 소요)
#
# DM 보단 카카오톡 문의가 답변이 빠릅니다
# (카톡상단돋보기누르기 -> bestdayever 친구추가 )
#
# 가격은 스마트스토어에서 확인 가능합니다
#
#
# - 인스타그램 아이디 : marquage.r
# - 팔로워 수 : 1,680
#
#
#  marquage.r (마카쥬랑)
#  반스커스텀, 1:1 맞춤 주문제작!!
#  생일선물, 기념일선물, 선물템
#  김해 마카쥬 ️가방,의류 토탈샵 ️
#  문의는 DM
#   주일은 휴무입니다
#
#
# - 인스타그램 아이디 : dear_my_blu2
# - 팔로워 수 : 58
#
#
# 포토 목걸이 / 키링 & 레터링 목걸이 / 키링 주문 제작 ꒰ ɞ̴̶̷ ·̮ ɞ̴̶̷ ꒱
# ⁎⁺˳✧༚ DM / 카카오톡 주문 ˚✧₊⁎
#
#
# - 인스타그램 아이디 : cholssak_label
# - 팔로워 수 : 1
#
#
# #촐싹라벨
# - 라벨스티커 커미션 받습니다
# - 문의는 DM 부탁드려요
#
#
# - 인스타그램 아이디 : iow_studio
# - 팔로워 수 : 95
#
#
# iow studio
# In other world
# “Imagination can unfold into reality.”
# 구월동 1235-2 1층
# 100%예약제 가죽공방
# 주문제작 및 클래스 문의 dm주세요
# Tel: 01057591372
#
#
# - 인스타그램 아이디 : 3rdhand_jewelry_studio
# - 팔로워 수 : 439
#
#
# 서드핸드_운서동주얼리공방
# 주문제작주얼리 #custommade
# 원데이,취미,전문강사 과정 수강문의 0507 1324 9992
# #영종도반지공방 #영종도은공방 #반지공방
# #graduatejeweler
# #artclaysilver instructor
#
#
# - 인스타그램 아이디 : flowershop_grandbleu
# - 팔로워 수 : 38
#
#
# 그랑블플라워 인천 연수구 동춘동 예쁜 꽃집입니다 인천,서울,경기지역 배송가능합니다. 영업시간 오전10시부터 오후9시 010-6775-5856
#
#
# - 인스타그램 아이디 : handmade.zip
# - 팔로워 수 : 336
#
#
#  핸드메이드 오  공식계정
# 핸드메이드에 관한 모든 것
# #핸드메이드오 #핸드메이드 #handmade #수제 #手作
#
#
# - 인스타그램 아이디 : flowershop_grandbleu
# - 팔로워 수 : 38
#
#
# 그랑블플라워 인천 연수구 동춘동 예쁜 꽃집입니다 인천,서울,경기지역 배송가능합니다. 영업시간 오전10시부터 오후9시 010-6775-5856
#
#
# - 인스타그램 아이디 : smartmoja_official
# - 팔로워 수 : 15,472
#
#
# 스냅백 볼캡 모자제작, 마스크캡 디자인특허 스마트모자입니다
# 커플 가족 동호회 팬클럽 프렌차이즈 모자!
# 1개부터 단체모자까지 고퀄리티 맞춤제작!
# 직통제작문의 : 010-3854-7256
# 카톡 아이디 : smoja
# 대표전화 : 1661-7256
# 스마트모자 홈페이지는
#
#
# - 인스타그램 아이디 : onuldo.calli
# - 팔로워 수 : 84
#
#
# 오늘도 캘리그라피 작가 @ 디자인연구소
# 캘리그라피 2,3급 자격증 취득
# 일러스트 액자 주문제작 dm 주세요 :)
# '일상의 소중함을 기록하고 담아두며 전달하는 일'
#
#
# - 인스타그램 아이디 : eunflower_silver
# - 팔로워 수 : 776
#
#
# 플로리스트 상상대표 이은희 #고덕신도시 #평택삼성꽃집#배달꽃집
# #평택꽃집 #평택고덕꽃집 #평택은공방 #평택고덕공방 #송탄꽃집 #평택고덕카페 #평택고덕플라워카페 #평택꽃다발 #은체험공방
# 주소: 고덕면 여염리 4482-5 상상
# 전화문의 031)653-1161
#
#
# - 인스타그램 아이디 : onuldo.calli
# - 팔로워 수 : 84
#
#
# 오늘도 캘리그라피 작가 @ 디자인연구소
# 캘리그라피 2,3급 자격증 취득
# 일러스트 액자 주문제작 dm 주세요 :)
# '일상의 소중함을 기록하고 담아두며 전달하는 일'
#
#
# - 인스타그램 아이디 : cake_staygajin
# - 팔로워 수 : 46
#
#
# ✿ 강원도 고성, 바닷가 앞 케이크 가게 ✿
#   매주 화요일 휴무 ◡̈
#   강원도 고성군 가진해변길 168 스테이가진
#   ➷ 주문, 문의는 아래 링크 클릭 ◡̈ ✿
#
#
# - 인스타그램 아이디 : yeojumallcom
# - 팔로워 수 : 120
#
#
# 여주도자인 온라인 쇼핑몰
# 여주몰의 공식 인스타그램입니다.
# [1+1] 만원의 행복 상품보러가기
#
#
# - 인스타그램 아이디 : silverin7
# - 팔로워 수 : 8,142
#
#
# ˢᴵᴸᵛᴱᴿᴿᴵᴺ
# ᴛᴀʟᴋ ɪᴅ: ᴍʜᴋ831124
#
#
# - 인스타그램 아이디 : jelly_d27
# - 팔로워 수 : 2
#
#
# 안녕하세요 젤리디자인입니다.
# 디자인스티커 네임스티커 방수네임스티커
# 디자인행거 주문제작/대량주문 가능
# 카카오플러스 : 젤리디자인  검색해주세용:)
#
#
# - 인스타그램 아이디 : do5mi5230
# - 팔로워 수 : 101
#
#
# 핸드매이드 공방
# 디퓨저/섬유향수/캔들/쉐비로즈/홈패션
# 조화꽃다발/답례품/행사품/
# 주문판매 및 수강
# 카톡ID_do5mi
# 전화 문자_010-3316-1545
# # 핸드메이드 #DIY
#
#
# - 인스타그램 아이디 : annestudio5
# - 팔로워 수 : 1,158
#
#
# 핸드메이드 테디베어
# 문의 : DM
# 이미지 무단사용 금지
#
#
# - 인스타그램 아이디 : snuglyn
# - 팔로워 수 : 492
#
#
# 🇸 🇳 🇺 🇬 🇱 🇾 🇳
#  만들고 싶은거 만들고 팔고 싶은거 가끔 팔아요
#  지금은 '필터교체용 마스크','쁘띠목도리' 상시주문 진행중
#  카카오채널 친구등록 후 언제든 문의가능 ੯‧̀͡u\
#
#
# - 인스타그램 아이디 : jiscakeboutique
# - 팔로워 수 : 549
#
#
# •Professor@LBCC
# •Pastry Chef@Ritz Carlton,Fourseasons, Roosevelt Hotel
# *Customized Cakes,Cupcakes in OC, LA
# *Licensed *Insured *Business Permit
#
#
# - 인스타그램 아이디 : 7816skok
# - 팔로워 수 : 20
#
#
#
#
# - 인스타그램 아이디 : cholssak_label
# - 팔로워 수 : 1
#
#
# #촐싹라벨
# - 라벨스티커 커미션 받습니다
# - 문의는 DM 부탁드려요
#
#
# - 인스타그램 아이디 : euna_embroidery
# - 팔로워 수 : 319
#
#
# 카페&공방 @cafe_oneul.haru 오늘,하루.
# 인천시 부평구 주부토로 151번길 31
# 부평구청역 3번출구
# -
# 프랑스자수 수업, 주문제작
# 뜨개, 패브릭 소품, 패브릭 인형 주문제작
# ( 문의 DM . 카톡ID : eunasoul )
#
#
# - 인스타그램 아이디 : sunny_atto
# - 팔로워 수 : 584
#
#
#   2015.07.08 아토
# 뛰는걸 아주 좋아하는 개들래미
# 세상 착한 내새끼
#  알바,부업 신고후,차단합니다
#
#
# - 인스타그램 아이디 : naesoneuro
# - 팔로워 수 : 795
#
#
# •#마크라메 제작판매 및 수업
# (원데이/정규/문화센터/단체수업/기업,학교출강)
# •kakaotalk : naesoneuro  링크클릭
#
#
# - 인스타그램 아이디 : lkst7708
# - 팔로워 수 : 286
#
#
# 144안시롱핀상시분양
# 우드펜.(볼펜.샤프) 플레이팅도마.빵도마.
# 주문제작. 가격문의.
#
#
# - 인스타그램 아이디 : nature.petglish
# - 팔로워 수 : 918
#
#
# 아로마테라피 스튜디오
# 관우맘's #유기견후원브랜드 #재능기부 #아로마테라피 #펫아로마테라피
# 본업 따로 있음- #영어동시통역사 /#영어강사 - #영어과외 문의 가능.
# #핸드메이드 #1대1맞춤제작
# #유기견보호소봉사 #유기견후원
# [상담&문의] 아래 링크 클릭 !!!
#
#
# - 인스타그램 아이디 : bbwood1234
# - 팔로워 수 : 434
#
#
# 원목으로 할 수 있는것들 웬만하면 다 해드립니다
#
#
# - 인스타그램 아이디 : amerisleep.ilsan
# - 팔로워 수 : 18
#
#
# 소비자 만족도 98% 매트리스 브랜드 , 100% 미국제조
# 친환경 식물성 매트리스
# 고양시 일산서구 덕이동 373-27 1층
#   031-912-1224
# #아메리슬립
#
#
# - 인스타그램 아이디 : ohio_furniture
# - 팔로워 수 : 776
#
#
#   오하이오 목공방
#   원목가구   합판가구   원데이클래스
#  대구광역시 수성구 범물동 1339-8 1층
#   010 9970 9136
#  kakao id : ohio2020
#  DM문의 : @ohio._.official
#
#
# - 인스타그램 아이디 : sangsang.flower
# - 팔로워 수 : 53
#
#
# 나만의 것_나만의 스타일을 추구하는 꽃
# 꽃- @eunflower_silver
# 실버-@anne.nana
# #평택꽃집 #평택고덕꽃집 #평택꽃다발 #평택상상 #상상
#
#
# - 인스타그램 아이디 : haen_drawing
# - 팔로워 수 : 46
#
#
# #라인드로잉 #일러스트
# 문의는 아래 링크로만 해주세요  (DM확인X)
#
#
# - 인스타그램 아이디 : haus_der_rose
# - 팔로워 수 : 393
#
#
# 100% 수제 도자기 ♡
# [디자인등록 중 ]
# 제작 기간은 평균 한달정도 소요됩니다.
# 별도 주문제작은 상담 후 가능합니다.
#
#
# - 인스타그램 아이디 : 0_topper
# - 팔로워 수 : 495
#
#
#  영토퍼
# 케이크 토퍼/기념일 토퍼/여행 토퍼/주문제작
# -
# ●카카오톡, 인스타 DM으로 상담 및 주문
#   (댓글은 상담받지 않습니다~)
# -
# ●카카오톡ID: 영토퍼(카카오톡 검색창에 검색)
#
#
# - 인스타그램 아이디 : faire_store2021
# - 팔로워 수 : 11
#
#
# 한땀한땀 정성과 사랑으로 꽃피우다
# 토탈 수공예품 스마트스토어를 준비하고 있어요
#
#
# - 인스타그램 아이디 : flowershop_grandbleu
# - 팔로워 수 : 38
#
#
# 그랑블플라워 인천 연수구 동춘동 예쁜 꽃집입니다 인천,서울,경기지역 배송가능합니다. 영업시간 오전10시부터 오후9시 010-6775-5856
#
#
# - 인스타그램 아이디 : nuricom815
# - 팔로워 수 : 12
#
#
#
#
# - 인스타그램 아이디 : hishands_atelier
# - 팔로워 수 : 649
#
#
# 가죽을 생각하고 자르고 바느질합니다
# 제작문의  dm  talk :HISHANDS
# 모든 작업물은 히즈핸즈의 소중한 디자인이에요
# 주문은 요기  링크 타고 들어오세요
#
#
# - 인스타그램 아이디 : lhonggi90
# - 팔로워 수 : 35
#
#
#
#
# - 인스타그램 아이디 : su.sue.now
# - 팔로워 수 : 57
#
#
# 여성복디자이너가 만드는 인형과의 커플룩~인형옷 그대로 여성복 주문제작.옷을 만드는 테크닉 개인레슨~키큰Su와 키작은Sue의~인형들과 함께 옷만드는 이야기~DM문의주세요
# ->@sucouture1203 (입체패턴/평면패턴/개인레슨)
#
#
# - 인스타그램 아이디 : si.sun_interior
# - 팔로워 수 : 149
#
#
# 시선이 닿는 곳에.
# 시선디자인연구소
#  인테리어.창호금속 DM문의
#
#
# - 인스타그램 아이디 : blue_selem
# - 팔로워 수 : 678
#
#
# 숲속 작은 보물, 셀렘
# 설레는 것을 담고싶은 공간 입니다
# .
# .
# silver925, 18K 주문제작
# 원데이클래스 반지만들기
# 문의 DM
# 카톡 KDM1929
# .
# .
# 반려동물인식표 @selem_pet
# (구)TCAFFEINE 티카페인
#
#
# - 인스타그램 아이디 : yoon8955
# - 팔로워 수 : 230
#
#
# 일일체험/단체체험
# /수강/출강/주문제작/판매
# 전화 0507-1363-1116
# #영주단체체험 #영주일일체험 #영주도자기 #영주체험 #가족체험
# #도자기공방 #도윤공방 #체험학습 #도자기페인팅자격증
# #세라믹페인팅
# #ceramicpainting
#
#
# - 인스타그램 아이디 : jroadcoffee
# - 팔로워 수 : 345
#
#
# "맛있는 커피는
# 좋은 생두로부터 시작된다."
#
# 좋은 생두를 선별하여
# 직접 로스팅한 원두만으로
#
# 꾸밈없이
# 속임없이
#
# 맛있는 한 잔의
# 커피를 전해드리겠습니다.
#
# ****
# ● 싱글&블렌딩 원두 유통, 납품
# ● 카페 창업반 1;1수업
# ● 커피 취미반 수업 커밍순!
#
#
# - 인스타그램 아이디 : patissiere_cake
# - 팔로워 수 : 577
#
#
# cafe  ️
# cake
# 군산케이크/군산카페
# -
#  10:00-20:00
# (저녁시간 5인이상예약시 1시간 연장)
#  서흥남동850-33
#  01081080117
#  kakao ID 파티시에르
#  DM 댓글
#
#
# - 인스타그램 아이디 : art__bebe
# - 팔로워 수 : 126
#
#
# 자체주문제작 핸드메이드 가방, 파우치, 앞치마 등
# 세상에 하나 밖에 없는 나만의 제품을 가질 수 있어요
# 선물, 행사, 기념품, 홍보용품 등 단체주문 가능
#  010-7633-2780
#
#
# - 인스타그램 아이디 : gold_star1019
# - 팔로워 수 : 4
#
#
#
#
# - 인스타그램 아이디 : by_hina
# - 팔로워 수 : 63
#
#
# 주문제작 핸드메이드 제품
#  구매/문의는 DM이나 아래  링크로 부탁 드립니다
#  디자인/사진의 무단 도용을 금지  합니다
# 문의시간 월~금 / am11:00~pm19:00
#
#
# - 인스타그램 아이디 : yuri_onsil
# - 팔로워 수 : 134
#
#
#  유리온실 - 꽃과 유리가 있는 공간⚘
#  Stained Glass & Ribbon
# ◇ 부산 정관신도시 스테인드글라스
# ◇ 소품 & 조명 주문제작 받아요
#
#
# - 인스타그램 아이디 : leeforbe_workroom
# - 팔로워 수 : 170
#
#
# -
# 가죽과 패브릭으로 만들고 전합니다.
# 아이디어스 '이포비워크룸'
# -
#  이포비워크룸 온라인 스토어와 블로그 링크
#
#
# - 인스타그램 아이디 : modernpoint_
# - 팔로워 수 : 2,093
#
#
# 하나의 사물, 공간의 가치를 더하다.
#
#
# - 인스타그램 아이디 : hoz_case
# - 팔로워 수 : 138
#
#
# HOZ LEATHER HAND MADE
# -
# 100%  핸드메이드  스마트 키케이스
# "좋은아이템은 차별화되는 디테일을 지녔다"
# -
# HOZ x Brightonmall
#
#
#
# - 인스타그램 아이디 : atelier_leeje
# - 팔로워 수 : 631
#
#
# 가죽공방
# 성북구 동소문로 13가길 37 1F
# 수업 및 주문제작 문의_카카오 ID : leeje2jae
#
#
# - 인스타그램 아이디 : myday_cake
# - 팔로워 수 : 465
#
#
#  My day with a cake!
#  우유생크림100%케이크
#  그림,로고작업
#  제과.제빵 국가기술자격증보유
#  서울 목동동로 189 127호(삼성쉐르빌1차 상가 안/경복궁 내려가는 계단 입구 앞)5호선 오목교역 8번출구 도보10분이내
# DM 카톡 주세요
#
#
# - 인스타그램 아이디 : b___o_h
# - 팔로워 수 : 920
#
#
# #슈가플로리스트
# #케잌작업실디자이너
# 카톡문의:qkqn1y
# "케이크 일주일전 예약 필수입니다"
# 디자인케이크/주문제작케이크/수업문의
# (취미반.원데이모집중)
#
# ⠀⠀⠀
# ⠀⠀⠀
#
#
# - 인스타그램 아이디 : 98_ricecake
# - 팔로워 수 : 36
#
#
# 본계정 @pjihye_827
# 졔졔의 발자취
# 퓨전 떡 케이크 입니다 :)
#
#
# - 인스타그램 아이디 : macaron_2f
# - 팔로워 수 : 251
#
#
# 마카롱제작실
#   11 : 30분 ~ 7시 (제품 소진시 마감)
#   경기도 안양시 만안구 덕천로 54 2층
# 명학역(1호선)2번 출구에서 1분/ 주차
#   070 4910 0067
# 카카오톡: 마카롱제작실
# 판매 선물포장 주문제작 원데이클래스
#
#
# - 인스타그램 아이디 : belicity_silver
# - 팔로워 수 : 43
#
#
# Made. 《silver》
# 작업공간
# 커스텀 문의 가능합니다.
# 모든 제품은 실버92.5로 제작됩니다.
#
#
# - 인스타그램 아이디 : florbeam
# - 팔로워 수 : 741
#
#
# 페이퍼플라워 /꽃풍선 /네온사인
# 클래스 - 원데이/취미반/자격증반
# 주문제작 - 선물용/공간디스플레이/포토존 등
# .
#  카톡 채널 - florbeam (플로르빔)
# .
#  솜씨당 수업신청 및 오시는 길
#
#
# - 인스타그램 아이디 : reum_illus
# - 팔로워 수 : 536
#
#
#   특별한 날
# 특별하게 쓰이다, 스티커맛집
# 상담 디엠을 사용하지 않아요
# 스마트스토어로 주문해주세요
#
#
# - 인스타그램 아이디 : iminjeong8545
# - 팔로워 수 : 2,229
#
#
# 하남매네 일상기록 *⑅  ︎
#
#
# - 인스타그램 아이디 : 7815skok
# - 팔로워 수 : 14
#
#
#
#
# - 인스타그램 아이디 : rococosofa.co.kr
# - 팔로워 수 : 5,806
#
#
# Timelss & Basic Furniture
# 세월이 흘러도 변치 않는 가구 브랜드
# -
#
#
# ...
#
#
# - 인스타그램 아이디 : the__label__
# - 팔로워 수 : 331
#
#
# 더라벨, 문의는 DM이나 톡톡으로 주세요
#
#
# - 인스타그램 아이디 : dodoha12345
# - 팔로워 수 : 898
#
#
# ⁣#선팔하면맞팔가요 ⁣ ⁣
#  365일⁣ 친절상담⁣/빠른답변
#  최고급⁣ 수입보세⁣/고퀄리티⁣ 레플리카⁣
#  매일⁣ 최신상⁣ 업데이트⁣ ⁣
#  빠른배송/직수입
# ⁣ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ⁣
#  ⁣제품문의/궁금하신점/배송문의 ⁣
#  아래링크를⁣⁣ 꾹~눌러주세요~
#
#
# - 인스타그램 아이디 : mopology_g
# - 팔로워 수 : 1,716
#
#
# 모든 문의는 사이트 게시판에 작성부탁드려요
# 전화나 문자는 확인이 어렵습니다
#
#
# - 인스타그램 아이디 : zzbe791229
# - 팔로워 수 : 70
#
#
#  바이제이
# 서문시장 2지구 지하1층 서216-1호
# 카톡IDzzb4444
# 카스ID바이제이
#  전국택배가능-5만원이상 무배
#  톡주시면 빠른답변 가능합니다
#  문의 및 주문은
#
#
# - 인스타그램 아이디 : fabre__official
# - 팔로워 수 : 447
#
#
#   소재와 적합한핏을 중요시하는 고퀄리티 여성의류
#   자체제작예정
#   매주 금요일 업데이트
#
#
# - 인스타그램 아이디 : mopology_g
# - 팔로워 수 : 1,716
#
#
# 모든 문의는 사이트 게시판에 작성부탁드려요
# 전화나 문자는 확인이 어렵습니다
#
#
# - 인스타그램 아이디 : apmlaundry_
# - 팔로워 수 : 14
#
#
# Wholesale
# Kakao : apmlaundry
# Wechat : apmlaundry
# Tel. 02 2250 1543
#  신상마켓
# 소매는 안해요
#
#
# - 인스타그램 아이디 : remember_company
# - 팔로워 수 : 7
#
#
# #Theot B1 I-19 #디오트 B1 I-19
# REMEMBER_official
# (#wholesale)리멤버(#도매)
#   T : 02-2117-4039
#  H.P : 010-3236-1449
# WE : Remember_shop
# KA : Remember2118
#
#
# - 인스타그램 아이디 : bwithu.official
# - 팔로워 수 : 3,978
#
#
#   APM PLACE 7F 714
#   02-2200-5245~6
#   010-9544-0787
# Kakaotalk : shorthill00
# Kakaostory : bwithu00
# Wechat : BwithU7 / BwithU77
# #동대문도매#여성의류#apmplace
#
#
# - 인스타그램 아이디 : yoniship
# - 팔로워 수 : 4,068
#
#
#  문의는카톡ID yoniship
# 교환 1회 환불불가하니 참고해주세요
# 택배가능  카드결제 디엠 댓글
# 토요일일요일휴무
#
#
# - 인스타그램 아이디 : luxlemonde
# - 팔로워 수 : 6,490
#
#
#  공장휴무공지
# ~2/7(일부2월수령) 2/7~ (3월순차적배송)
# -
# 무통장입금시 전품목 10% 할인
# -
# 도매/창업/제휴 문의가능
# -
#  KaKaoTalk center   럭스르몽드
# open 10:00 - close 18:00
# -
# 인스타 전 제품 카톡구매가능
#
#
# - 인스타그램 아이디 : loveyomi_90
# - 팔로워 수 : 166
#
#
#  모든 문의 사항
# 레이미상호였습니다, 무슨사유로 상호명이전했어요
#
#
# - 인스타그램 아이디 : e_unji21
# - 팔로워 수 : 358
#
#
# 나의 #아이폰 12
#
#
# - 인스타그램 아이디 : k_mj_jj
# - 팔로워 수 : 310
#
#
# 하루를특별하게 만들어주는 모먼트데이
#
#
# - 인스타그램 아이디 : mopology_g
# - 팔로워 수 : 1,716
#
#
# 모든 문의는 사이트 게시판에 작성부탁드려요
# 전화나 문자는 확인이 어렵습니다
#
#
# - 인스타그램 아이디 : klbylynn
# - 팔로워 수 : 53
#
#
#  ︎ 매일매일 신상 업뎃!
# _
#  ︎ 네이버 스토어팜 바로가기
#
#
# - 인스타그램 아이디 : shop_503
# - 팔로워 수 : 8,729
#
#
# 42918, JUKGOK 1GIL-10, DASA-EUP
# DALSEOUNG-GUN, DAEGU
# @503.house
#
#
# - 인스타그램 아이디 : mippeni0402
# - 팔로워 수 : 1,529
#
#
#   1:1 high quality 수입의류전문
#   온라인쇼핑몰 : www.mippeni.com
#   문의는 카톡 : mippeni & DM
#   카스 매일 신상업뎃 (링크클릭 )
#
#
# - 인스타그램 아이디 : a.high_1
# - 팔로워 수 : 777
#
#
# 쇼핑몰 상세페이지 화질이 깨져서 개선 될때까지
# 쇼핑몰에 없는 신상품도 시즌상품 파격세일도
# 모두 인스타로 진행해볼까 합니다
# 문의사항은 언제든 디엠 주세요
#
#
#
# - 인스타그램 아이디 : ram.fic
# - 팔로워 수 : 21
#
#
#
#
# - 인스타그램 아이디 : mippeni0402
# - 팔로워 수 : 1,529
#
#
#   1:1 high quality 수입의류전문
#   온라인쇼핑몰 : www.mippeni.com
#   문의는 카톡 : mippeni & DM
#   카스 매일 신상업뎃 (링크클릭 )
#
#
# - 인스타그램 아이디 : shop_503
# - 팔로워 수 : 8,729
#
#
# 42918, JUKGOK 1GIL-10, DASA-EUP
# DALSEOUNG-GUN, DAEGU
# @503.house
#
#
# - 인스타그램 아이디 : queenssquare.official
# - 팔로워 수 : 21,152
#
#
# 777, Sindang-Dong, Jung-gu
# Seoul, Korea
#
# Contact +82 2-6970-7500
#
#
# - 인스타그램 아이디 : mippeni0402
# - 팔로워 수 : 1,529
#
#
#   1:1 high quality 수입의류전문
#   온라인쇼핑몰 : www.mippeni.com
#   문의는 카톡 : mippeni & DM
#   카스 매일 신상업뎃 (링크클릭 )
#
#
# - 인스타그램 아이디 : jiwon_9285
# - 팔로워 수 : 383
#
#
#
#
# - 인스타그램 아이디 : double.one.ent
# - 팔로워 수 : 340
#
#
# 안녕하세요. 모델에이전시, 촬영회 진행중입니다 :)
#
#
# - 인스타그램 아이디 : rangsstudio
# - 팔로워 수 : 723
#
#
# 새상품만 3일이내 교환, 환불 가능합니다.
# 배송비 3000원은 별도입니다.
# 빈티지제품은 새제품이 아니므로
# 약간의 사용감이 있을 수 있으니 유의해주세요.
# ↓↓↓ 꾹 눌러주심 쥔장과 카톡연결
#
#
# - 인스타그램 아이디 : mix_22530433
# - 팔로워 수 : 7,880
#
#
# MIX
# Queen's square 5F 535 , 538
# 02.6970.7289
# 010.5576.7289
# wholesale
#
#
# - 인스타그램 아이디 : bleecker_official_
# - 팔로워 수 : 1,537
#
#
# Queen’s Square 3F 105
# 02.6970.7226 / 010.6878.7226
# Kakaotalk : BLEECKERshop
# 신상마켓 : Bleecker
# Kakaostory : Bleecker_story
# Wechat : Bleecker_wechat
#
#
# - 인스타그램 아이디 : _two_.guys_
# - 팔로워 수 : 289
#
#
# 국내 홈웨어 잠옷 전문 NO.1 / 투가이즈 스토어팜
# 𝕀 𝕘𝕚𝕧𝕖 𝕪𝕠𝕦 𝕒 𝕔𝕠𝕞𝕗𝕠𝕣𝕥𝕒𝕓𝕝𝕖 𝕟𝕚𝕘𝕙𝕥.
#   투가이즈 네어버스토어팜 클릭
#
#
# - 인스타그램 아이디 : merry_bokeo
# - 팔로워 수 : 33,041
#
#
# Since 2016
# 좋아서 하는일, 옷에 진심인 편
# -
#   open ; (MADE) 꾸안꾸 밴딩 팬츠 / 기모
# -
# Showroom ) 부산 정관신도시 모전2길 35, 1층
# 3월부터 확장 이전한 쇼룸에서 뵈어요
#
#
# - 인스타그램 아이디 : you__made_myday
# - 팔로워 수 : 174
#
#
# •Open am10:00-pm18:00
# •CS 네이버톡톡
# •스토어찜 2000원 할인쿠폰증정
# •전체상품을 클릭하시면 모든 상품을 볼 수 있습니다
#
#
# - 인스타그램 아이디 : jmont_official
# - 팔로워 수 : 17,859
#
#
# 1/15(금)-트웨이드 리미티드 live 방송
# 1/25(월)-리미티드 프리오더2 live 방송
# •자체디자인제작shop
#  압구정점 @jmont_design
# .
#  논현점180-18.1F/톡:jmont8881
#
#
# - 인스타그램 아이디 : shop_503
# - 팔로워 수 : 8,729
#
#
# 42918, JUKGOK 1GIL-10, DASA-EUP
# DALSEOUNG-GUN, DAEGU
# @503.house
#
#
# - 인스타그램 아이디 : bboshong___
# - 팔로워 수 : 332
#
#
# ෆ̈ввσѕнσиg(뽀숑)ෆ̈
# 테크노(techno)2F 219-220호
# 도매 ️, 소매
#  01067251107
# wechat ID: bboshong77
# Katalk ID: bboshong1107
# 신상마켓:뽀숑
#
#
# - 인스타그램 아이디 : baba__oh
# - 팔로워 수 : 228
#
#
#  Ｗｏｍｏｎ Ｌｏｏｋ
# •
# MON-SAT 11:00 ~ 21:00 (SUN OFF)
# ~ShowRoom~전북 익산시 모현동1가 339
# 제품 및 배송 관련 문의는 DM&톡 부탁드려요
#
#
# - 인스타그램 아이디 : likevam.buttern
# - 팔로워 수 : 712
#
#
# Queen’s 4F 39 Likevam
# @butter_en @likevam
# Wechat : Likevam_
# 카카오스토리 : likevam/버터앤
# Tel : 010 8313 5101
# 신상마켓 : 라이크밤 / 버터앤
#
#
# - 인스타그램 아이디 : jnjoy__
# - 팔로워 수 : 99
#
#
# ♡︎ 제이엔조이 -> ᴊɴᴊᴏʏ ♡︎
# ➪ #제품문의dm
# ➪ 이쁘고 슬림한 #오늘의코디
# ➪ 𝕤𝕚𝕫𝕖 𝟻𝟻-𝟽𝟽.𝟻 ꕥ
# ☟︎ 𝕁ℕ𝕁𝕆𝕐 상세 구매 링크  ☟︎
#
#
# - 인스타그램 아이디 : sss__se__
# - 팔로워 수 : 1,438
#
#
# open 11:00 - 21:00
# @season___official
#  네이버검색창에 'shopseason'
# http://m.smartstore.naver.com/shopseason
#
#
# - 인스타그램 아이디 : bbbr__
# - 팔로워 수 : 1,667
#
#
#  르멜리아
#  Kakaotalk . bbbrr
#  상품문의 . 카카오톡, DM
#
#
# - 인스타그램 아이디 : _1271rich
# - 팔로워 수 : 677
#
#
#  카톡 > 1271rich
#  모든 문의는 > DM
#  아래 사이트 이용해주세요!
# .
# .
#
#
# - 인스타그램 아이디 : jian8796
# - 팔로워 수 : 3,825
#
#
# Queen’s Square 2F 5호
# @liveaid_official_
#   : 02) 6970 7409
# H.P : 010 3535 8796
#  kakaotalk ID : youmi0529
#  wechat ID : youmi529
#
#
# - 인스타그램 아이디 : bygreenday
# - 팔로워 수 : 671
#
#
# - 2015년 5월 6일생 내사랑 콩시키   +
# - 좋아하는 것들, 그리고 one fine day
# - 일상와 일탈사이
#  꽃계정은 여기에요 @bygreenday_fleur
#
#
# - 인스타그램 아이디 : roa_31_
# - 팔로워 수 : 22
#
#
# #roadshop#주문가능#택배 ️
# 문의 디엠.
# 위치   부산대1번출구, 자라옆
#
#
# - 인스타그램 아이디 : chicfox_v
# - 팔로워 수 : 8,718
#
#
# [ 일상이 특별해지는 #데일리룩 ]
# #시크폭스
# #프리미엄진 #여우진
# #키작은여성 #바지핏 #키작녀
# #자체제작
#
# ⚂ 홈페이지 구경가기~
#
#
# - 인스타그램 아이디 : smartstore.sdplan
# - 팔로워 수 : 211
#
#
# 발이편한신발
# 몸이편한의류
# S925실버 쥬얼리
# 뷰티브랜드
# 스마트스토어 SD플랜
#
#
# - 인스타그램 아이디 : koco_vietnam
# - 팔로워 수 : 140
#
#
# Thời trang nữ cao cấp
# Made in Korea
# Nhập khẩu trực tiếp từ Hàn Quốc
# _
#  Follow me
# https://bit.ly/KOCO_Youtube
#
#
# - 인스타그램 아이디 : april_lovelydam
# - 팔로워 수 : 513
#
#
# 인천 서구 청라커낼로288번길 8-10 청라 봄빌딩
# #fashionstylist 자격증
# 전상품 #무료배송 해드립니다
# 사랑스러운 당신을위한 #여성의류
#
#
# - 인스타그램 아이디 : come_french
# - 팔로워 수 : 15,432
#
#
# 내가 입고싶은 옷, 오래오래 입을 수 있는 옷들만
# (+문의는 사이트로 해주세요-! 디엠 확인 X)
#  해외배송 문의는 DM 보내실때
# [해외배송 문의]를 메시지 제일 앞에 달아서 보내주세요!
# -
# 아무의미없는 타업체 댓글 무통보 삭제
# 댓글은 서로 예의를 지키기로 해요
#
#
# - 인스타그램 아이디 : insta_love_m
# - 팔로워 수 : 1,856
#
#
# SN L 3
# Freelance model
# A hospital administrator
#
#
# - 인스타그램 아이디 : bboshong___
# - 팔로워 수 : 332
#
#
# ෆ̈ввσѕнσиg(뽀숑)ෆ̈
# 테크노(techno)2F 219-220호
# 도매 ️, 소매
#  01067251107
# wechat ID: bboshong77
# Katalk ID: bboshong1107
# 신상마켓:뽀숑
#
#
# - 인스타그램 아이디 : rani._style
# - 팔로워 수 : 74
#
#
# #여성#의류쇼핑몰#최저가#카드환영
# 상품보기.제품구매.가격문의  카톡 DM
#
#
# - 인스타그램 아이디 : luxlemonde
# - 팔로워 수 : 6,490
#
#
#  공장휴무공지
# ~2/7(일부2월수령) 2/7~ (3월순차적배송)
# -
# 무통장입금시 전품목 10% 할인
# -
# 도매/창업/제휴 문의가능
# -
#  KaKaoTalk center   럭스르몽드
# open 10:00 - close 18:00
# -
# 인스타 전 제품 카톡구매가능
#
#
# - 인스타그램 아이디 : se_.young___
# - 팔로워 수 : 223
#
#
# @be_om.jun
#
#
# - 인스타그램 아이디 : kuzuring
# - 팔로워 수 : 248
#
#
# #유니크#트렌디#데일리#아이템#여성쇼핑몰#여성의류#쇼핑몰
# @yyyym__i
# 네이버 “쿠주링” 검색
#
#
# - 인스타그램 아이디 : a___reum__
# - 팔로워 수 : 910
#
#
#
#
# - 인스타그램 아이디 : iyun413
# - 팔로워 수 : 941
#
#
#   여성의류 루키
#   광주금남지하도상가 O동3호
#   010.8612.0590
#  DM보내지 마시고 문자나 전화 주세요
# ♡ 인스타그램 첫 주문 고객님은 20% 할인합니다.
#
#
# - 인스타그램 아이디 : likevam.buttern
# - 팔로워 수 : 712
#
#
# Queen’s 4F 39 Likevam
# @butter_en @likevam
# Wechat : Likevam_
# 카카오스토리 : likevam/버터앤
# Tel : 010 8313 5101
# 신상마켓 : 라이크밤 / 버터앤
#
#
# - 인스타그램 아이디 : titleistfj_cheongju
# - 팔로워 수 : 308
#
#
# 타이틀리스트.풋조이 청주점입니다.
# 충청북도 청주시 서원구 미평동110번지 (도로명)청남로1874
# 043-284-3989/am10:30~pm9:00
# ※상품관련 문의는 전화주세요※
#
#
# - 인스타그램 아이디 : mopology_g
# - 팔로워 수 : 1,715
#
#
# 모든 문의는 사이트 게시판에 작성부탁드려요
# 전화나 문자는 확인이 어렵습니다
#
#
# - 인스타그램 아이디 : wonderplace_jamsil
# - 팔로워 수 : 163
#
#
# 서울특별시 송파구 올림픽로 300 5F
# (서울특별시 송파구 신천동 29 5F)
#   Tel : 02-3213-4510
#  Open AM 10:30
#  Close PM 10:00
#  DM확인이 늦어 질 수 있으니 매장으로 문의 부탁드립니다.
#
#
# - 인스타그램 아이디 : bbbr__
# - 팔로워 수 : 1,667
#
#
#  르멜리아
#  Kakaotalk . bbbrr
#  상품문의 . 카카오톡, DM
#
#
# - 인스타그램 아이디 : s._0309
# - 팔로워 수 : 1,047
#
#
#   공구진행
#  문의DM
#
#
# - 인스타그램 아이디 : jinparty
# - 팔로워 수 : 10,029
#
#
# #협찬DM문의환영
# #여행스타그램 #먹방스타그램 #운동스타그램
#
#
# - 인스타그램 아이디 : mi_m_omimo
# - 팔로워 수 : 212
#
#
#  쇼핑 및 유통
#  20대가 추천하는 핫플샵
#  여성의류 인스타 마켓
#  가격으로 어필해요~!
#  90%할인된 가격에 구매 쌉가능
#  도매가 보다 더 저렴한 온라인 쇼핑 쌉가능
#  쇼핑1급 비밀 핵저렴
#  매일 한정판 업로드 꿀득탬
#  문의.주문 DM
#
#
# - 인스타그램 아이디 : r._.aon
# - 팔로워 수 : 306
#
#
# 2018. 08. 07
#
#
# - 인스타그램 아이디 : bluebelle.co.kr
# - 팔로워 수 : 1,789
#
#
# 멋진 데일리룩,센스있는 스타일
# 여성의류&여성슈즈&악세사리
# .
#   02-596-6807/PM1:00~PM6:00
#
#
# - 인스타그램 아이디 : id_studio209
# - 팔로워 수 : 1,630
#
#
# ▘
# ᵂᴴᴼᴸᴱˢᴬᴸᴱ
# 아이디 스튜디오(도매)AᴘᴍPʟᴀᴄᴇ 2̆̈𝗙209
# 신상마켓 - ᴀᴘᴍPʟᴀᴄᴇ209
# Kᴀᴋᴀᴏ̈ᴛᴀʟᴋ - ɪ̇𝚍sᴛᴜ𝚍𝚒ᴏ̈
# Kᴀᴋᴀᴏ̈sᴛᴏ̈ʀʏ- ᴀᴘᴍPʟᴀᴄᴇ 209
# 𝚆𝚎ᴄ̧ʜᴀᴛ- ɪ̇𝚍sᴛᴜ𝚍𝚒ᴏ̈ 209
# ☏ 02-2200-5929
#
#
# - 인스타그램 아이디 : _fortuna______
# - 팔로워 수 : 787
#
#
#  대전 서구 관저동 1517번지 117호
#  12:30-21:00 (휴무는 인스타 참고)
#   주문, 문의사항은 디엠으로 주세용
#
#
# - 인스타그램 아이디 : _boutiqueshopp_
# - 팔로워 수 : 438
#
#
# 명품 파는 언니
# #명품 #해외구매대행 #최저가공구
#  배송 주말 내외 2~5일 소요
#  피드에 없는 상품 문의 가능
#  DM 확인은 조금 늦을 수 있어요
#  카드/현금 결제 가능
#
#
# - 인스타그램 아이디 : queenssquare.official
# - 팔로워 수 : 21,152
#
#
# 777, Sindang-Dong, Jung-gu
# Seoul, Korea
#
# Contact +82 2-6970-7500
#
#
# - 인스타그램 아이디 : ______outfit
# - 팔로워 수 : 932
#
#
# 365일 무료배송
# 신생 블로그마켓입니다
# 배송문의는 디엠 또는 연락처로 문의해주세요!
# 선팔하면 맞팔/문의   DM
#   카카오톡 플러스친구 “oufit아웃핏” 검색!
#
#
# - 인스타그램 아이디 : queenssquare.official
# - 팔로워 수 : 21,152
#
#
# 777, Sindang-Dong, Jung-gu
# Seoul, Korea
#
# Contact +82 2-6970-7500
#
#
# - 인스타그램 아이디 : cocogen11
# - 팔로워 수 : 928
#
#
#  직수입 의류 쇼핑몰 cocogen
#  합리적인 가격으로 만나보세요~
#  쇼핑몰사이트 및 문의   링크클릭
#
#
# - 인스타그램 아이디 : red_chu25
# - 팔로워 수 : 172
#
#
#  현지 해외구매대행 업체
#  명품 ‘바잉’대행입니다 ️ ️
#  카카오톡으로 문의 주세요
#    구매대행 레드츄
#  더많은 제품정보 카톡   black9401
#
#
# - 인스타그램 아이디 : smartstore.sdplan
# - 팔로워 수 : 211
#
#
# 발이편한신발
# 몸이편한의류
# S925실버 쥬얼리
# 뷰티브랜드
# 스마트스토어 SD플랜
#
#
# - 인스타그램 아이디 : po__in
# - 팔로워 수 : 91,560
#
#
# beauty • fashion
# 문의는 DM ʚ   ʚ
#
#
# - 인스타그램 아이디 : loveyomi_90
# - 팔로워 수 : 166
#
#
#  모든 문의 사항
# 레이미상호였습니다, 무슨사유로 상호명이전했어요
#
#
# - 인스타그램 아이디 : queenssquare.official
# - 팔로워 수 : 21,152
#
#
# 777, Sindang-Dong, Jung-gu
# Seoul, Korea
#
# Contact +82 2-6970-7500
#
#
# - 인스타그램 아이디 : rangsstudio
# - 팔로워 수 : 723
#
#
# 새상품만 3일이내 교환, 환불 가능합니다.
# 배송비 3000원은 별도입니다.
# 빈티지제품은 새제품이 아니므로
# 약간의 사용감이 있을 수 있으니 유의해주세요.
# ↓↓↓ 꾹 눌러주심 쥔장과 카톡연결
#
#
# - 인스타그램 아이디 : jejesty1e
# - 팔로워 수 : 1,602
#
#
# 바배 의류 @jejestvip
# 명품 가방 @blancbag
# 남성 의류 @blancmanshop
# 키즈 의류 @jejestkids
# ❦주문 및 문의 상담은 하단에 오픈 카톡으로 연락 주시면 빠른 상담 가능하십니다.
# EMS 해외배송 10일-15일 ✆ 카카오톡 링크⤾
#
#
# - 인스타그램 아이디 : jungmar2
# - 팔로워 수 : 2,006
#
#
# 실룩실룩CEO #에스에스엔모리 대표
#
#
# - 인스타그램 아이디 : bluebelle.co.kr
# - 팔로워 수 : 1,789
#
#
# 멋진 데일리룩,센스있는 스타일
# 여성의류&여성슈즈&악세사리
# .
#   02-596-6807/PM1:00~PM6:00
#
#
# - 인스타그램 아이디 : dressup__official
# - 팔로워 수 : 331
#
#
# Dot b1 j5 <dress up>-wholesale
# www.thedressup.co.kr
# Phone:010-7617-7756
# kakao talk:dressup1
# Wechat id:dressup-b1j5
# 신상마켓:드레스업 dressup
# 자체제작&주문문의 DM주세요
#
#
# - 인스타그램 아이디 : hyeonji336
# - 팔로워 수 : 106
#
#
# #럽스타그램 #커플 #여행 #여행스타스램
#
#
# - 인스타그램 아이디 : loveyomi_90
# - 팔로워 수 : 166
#
#
#  모든 문의 사항
# 레이미상호였습니다, 무슨사유로 상호명이전했어요
#
#
# - 인스타그램 아이디 : do___e2
# - 팔로워 수 : 411
#
#
#  ᴊᴏᴏ_ɪ
#  남성의류 @hj_0728_
# -문의 ᴅᴍ&카톡: tnsghk2131
# -팔로우 해주시면 모든상품 1000원 할인권
# -1:1 마케터  원하시는 디자인 캡쳐 후
# 문의 주시면 무조건 저렴한 가격에 출고
# 모두Ⓓ 주세용>‿<✿
#
#
# - 인스타그램 아이디 : loveyomi_90
# - 팔로워 수 : 166
#
#
#  모든 문의 사항
# 레이미상호였습니다, 무슨사유로 상호명이전했어요
#
#
# - 인스타그램 아이디 : by_ma_belle
# - 팔로워 수 : 6,200
#
#
# @ma_belle_official
#
#
# - 인스타그램 아이디 : queenssquare.official
# - 팔로워 수 : 21,152
#
#
# 777, Sindang-Dong, Jung-gu
# Seoul, Korea
#
# Contact +82 2-6970-7500
#
#
# - 인스타그램 아이디 : seria_shopping_shop
# - 팔로워 수 : 611
#
#
# 쇼핑및유통
#
#
# - 인스타그램 아이디 : v_rin00
# - 팔로워 수 : 81
#
#
# 많은 관심 부탁드려요
#
#
# - 인스타그램 아이디 : apmlaundry_
# - 팔로워 수 : 15
#
#
# Wholesale
# Kakao : apmlaundry
# Wechat : apmlaundry
# Tel. 02 2250 1543
#  신상마켓
# 소매는 안해요
#
#
# - 인스타그램 아이디 : backstage_studio_
# - 팔로워 수 : 1,042
#
#
#  offline showroom
# Pm3-Pm11
# 제주도 제주시 연동 7길 27
#  online store
#
#
#
# - 인스타그램 아이디 : soyi__2
# - 팔로워 수 : 375
#
#
# Belle et Noble
#
#
# - 인스타그램 아이디 : by_seeyou4
# - 팔로워 수 : 346
#
#
# 수입명품/수입의류 판매중
# "sold out"이 빠릅니다. 서둘러주세요.
# 스페셜오더 싱크로율 99.9% 상품
# 정품가죽과 원단을 사용하여 제작
# .
#  댓글문의 NO~
# 빠른답변 원하시면 카톡주세요.
#  문의.주문하기/더많은상품보기
#
#
# - 인스타그램 아이디 : apmlaundry_
# - 팔로워 수 : 15
#
#
# Wholesale
# Kakao : apmlaundry
# Wechat : apmlaundry
# Tel. 02 2250 1543
#  신상마켓
# 소매는 안해요
#
#
# - 인스타그램 아이디 : mesuga_official
# - 팔로워 수 : 198
#
#
# open.11:00am-7:00pm (월~토)
# close.일요일/공휴일
# -
# 경기 고양시 일산서구 중앙로1470 동부썬프라자 1층107호
# #mesuga #미슈가 #주차가능
# site
#
#
# - 인스타그램 아이디 : _1271rich
# - 팔로워 수 : 677
#
#
#  카톡 > 1271rich
#  모든 문의는 > DM
#  아래 사이트 이용해주세요!
# .
# .
#
#
# - 인스타그램 아이디 : yoniship
# - 팔로워 수 : 4,068
#
#
#  문의는카톡ID yoniship
# 교환 1회 환불불가하니 참고해주세요
# 택배가능  카드결제 디엠 댓글
# 토요일일요일휴무
#
#
# - 인스타그램 아이디 : reneevon_cheongju
# - 팔로워 수 : 342
#
#
# #여성의류 / #오피스룩
# #데일리룩 /#하객패션
# #오오티디 /#OOTD
#
#
# - 인스타그램 아이디 : maylily_gong9
# - 팔로워 수 : 9,755
#
#
#  메이릴리 공동구매샵
#  인테리어소품 공동구매
# #Vintage #Antique #소품공구
#   예쁜옷 문의  @ccontti_go
# -
#  마카롱 문의 @maylily709.1
# -
#  문의상담  카드결제가능
# 010.8867.7793
# 인스타dm
#
#
# - 인스타그램 아이디 : loveyomi_90
# - 팔로워 수 : 166
#
#
#  모든 문의 사항
# 레이미상호였습니다, 무슨사유로 상호명이전했어요
#
#
# - 인스타그램 아이디 : id_studio209
# - 팔로워 수 : 1,630
#
#
# ▘
# ᵂᴴᴼᴸᴱˢᴬᴸᴱ
# 아이디 스튜디오(도매)AᴘᴍPʟᴀᴄᴇ 2̆̈𝗙209
# 신상마켓 - ᴀᴘᴍPʟᴀᴄᴇ209
# Kᴀᴋᴀᴏ̈ᴛᴀʟᴋ - ɪ̇𝚍sᴛᴜ𝚍𝚒ᴏ̈
# Kᴀᴋᴀᴏ̈sᴛᴏ̈ʀʏ- ᴀᴘᴍPʟᴀᴄᴇ 209
# 𝚆𝚎ᴄ̧ʜᴀᴛ- ɪ̇𝚍sᴛᴜ𝚍𝚒ᴏ̈ 209
# ☏ 02-2200-5929
#
#
# - 인스타그램 아이디 : red_chu25
# - 팔로워 수 : 172
#
#
#  현지 해외구매대행 업체
#  명품 ‘바잉’대행입니다 ️ ️
#  카카오톡으로 문의 주세요
#    구매대행 레드츄
#  더많은 제품정보 카톡   black9401
#
#
# - 인스타그램 아이디 : mippeni0402
# - 팔로워 수 : 1,529
#
#
#   1:1 high quality 수입의류전문
#   온라인쇼핑몰 : www.mippeni.com
#   문의는 카톡 : mippeni & DM
#   카스 매일 신상업뎃 (링크클릭 )
#
#
# - 인스타그램 아이디 : _blancmiel
# - 팔로워 수 : 7,388
#
#
# • 천안지역 퀵 가능, 택배가능
# • 사이트는 당분간 쉬어갑니다
# • DM은 누락되거나 확인이 늦을 수 있어요
#   문의는 오픈카톡으로 연락주세요
#
#
# - 인스타그램 아이디 : cocogen11
# - 팔로워 수 : 928
#
#
#  직수입 의류 쇼핑몰 cocogen
#  합리적인 가격으로 만나보세요~
#  쇼핑몰사이트 및 문의   링크클릭
#
#
# - 인스타그램 아이디 : jnjoy__
# - 팔로워 수 : 99
#
#
# ♡︎ 제이엔조이 -> ᴊɴᴊᴏʏ ♡︎
# ➪ #제품문의dm
# ➪ 이쁘고 슬림한 #오늘의코디
# ➪ 𝕤𝕚𝕫𝕖 𝟻𝟻-𝟽𝟽.𝟻 ꕥ
# ☟︎ 𝕁ℕ𝕁𝕆𝕐 상세 구매 링크  ☟︎
#
#
# - 인스타그램 아이디 : mone9281
# - 팔로워 수 : 648
#
#
# 퀸즈 스퀘어 2층81호 바니블러쉬
# Queen’s Square 2F-81 Bani Blush
#  Tel 02-6970-7408
#  HP 010-8557-2081(샘플문의)
#  Wechat : baniblush281
#
#
# - 인스타그램 아이디 : asome_company
# - 팔로워 수 : 5,458
#
#
#  asome wholesale
#  Apm 3-4 : asome
#  02.2250.0627
# wechat : asome304
# kakaostory : asome304
#
#
# - 인스타그램 아이디 : nanimori2021
# - 팔로워 수 : 9
#
#
# nani mori
# #여성수입의류  전문
#
#
# - 인스타그램 아이디 : by.hongvely
# - 팔로워 수 : 1,392
#
#
#
#
# - 인스타그램 아이디 : moodlabel_ziyeon
# - 팔로워 수 : 27
#
#
# 매일매일 잘 입어지는 데일리룩
# 편안함에 무드를 더하다
# @moodlabel2020
#
#
# - 인스타그램 아이디 : eunn0ia
# - 팔로워 수 : 360
#
#
#
#
# - 인스타그램 아이디 : ____168.mn
# - 팔로워 수 : 1,041
#
#
#
#
# - 인스타그램 아이디 : mippeni0402
# - 팔로워 수 : 1,529
#
#
#   1:1 high quality 수입의류전문
#   온라인쇼핑몰 : www.mippeni.com
#   문의는 카톡 : mippeni & DM
#   카스 매일 신상업뎃 (링크클릭 )
#
#
# - 인스타그램 아이디 : loveyomi_90
# - 팔로워 수 : 166
#
#
#  모든 문의 사항
# 레이미상호였습니다, 무슨사유로 상호명이전했어요
#
#
# - 인스타그램 아이디 : hangerisgood
# - 팔로워 수 : 7,511
#
#
# 모든 제품은 아래 사이트에서 확인해주세요 ෆ
#
#
# - 인스타그램 아이디 : naturalstay_sowon
# - 팔로워 수 : 144
#
#
# 예쁘고 편한옷 편집샵♡
# 내츄럴룩 린넨의류 매니아 주인장 취향의 옷 셀렉
# 옷느낌 가격 구매 문의 소통 환영요 ♡♡ 댓글 또는 DM주세요
#
#
# - 인스타그램 아이디 : lovecocomaton
# - 팔로워 수 : 1,899
#
#
# @cocomaton_offical
# Queens square 2f85
# Tel)02.6970.7311
# Kakaotalk :babymimi5055
# Wechat : babymimi5055
#
#
# - 인스타그램 아이디 : _two_.guys_
# - 팔로워 수 : 290
#
#
# 국내 홈웨어 잠옷 전문 NO.1 / 투가이즈 스토어팜
# 𝕀 𝕘𝕚𝕧𝕖 𝕪𝕠𝕦 𝕒 𝕔𝕠𝕞𝕗𝕠𝕣𝕥𝕒𝕓𝕝𝕖 𝕟𝕚𝕘𝕙𝕥.
#   투가이즈 네어버스토어팜 클릭
#
#
# - 인스타그램 아이디 : apmlaundry_
# - 팔로워 수 : 15
#
#
# Wholesale
# Kakao : apmlaundry
# Wechat : apmlaundry
# Tel. 02 2250 1543
#  신상마켓
# 소매는 안해요
#
#
# - 인스타그램 아이디 : jinparty
# - 팔로워 수 : 10,029
#
#
# #협찬DM문의환영
# #여행스타그램 #먹방스타그램 #운동스타그램
#
#
# - 인스타그램 아이디 : asome_company
# - 팔로워 수 : 5,459
#
#
#  asome wholesale
#  Apm 3-4 : asome
#  02.2250.0627
# wechat : asome304
# kakaostory : asome304
#
#
# - 인스타그램 아이디 : kkoongji
# - 팔로워 수 : 610
#
#
#
#
# - 인스타그램 아이디 : queenssquare.official
# - 팔로워 수 : 21,152
#
#
# 777, Sindang-Dong, Jung-gu
# Seoul, Korea
#
# Contact +82 2-6970-7500
#
#
# - 인스타그램 아이디 : kuzuring
# - 팔로워 수 : 248
#
#
# #유니크#트렌디#데일리#아이템#여성쇼핑몰#여성의류#쇼핑몰
# @yyyym__i
# 네이버 “쿠주링” 검색
#
#
# - 인스타그램 아이디 : __hyem1
# - 팔로워 수 : 992
#
#
# God bless me.
# 스토어찜,소식알림 2000원 할인!
# 문의는 dm,톡톡으로 주세요
#
#
# - 인스타그램 아이디 : mippeni0402
# - 팔로워 수 : 1,529
#
#
#   1:1 high quality 수입의류전문
#   온라인쇼핑몰 : www.mippeni.com
#   문의는 카톡 : mippeni & DM
#   카스 매일 신상업뎃 (링크클릭 )
#
#
# - 인스타그램 아이디 : seungamarket
# - 팔로워 수 : 669
#
#
# #bohemian #unique #vintage #누죤지하2층617호 #가죽신발 #옷
#  밤시장이라서 저녁8시부터 새벽 4시까지/디엠 남겨주세요
# 카카오톡 창에 '승아마켓' 입력하시고 채널 추가해 주세요
# 디엠주문가능 카톡주문가능 사업자환영
#  010 2243 4171
#
#
# - 인스타그램 아이디 : you__made_myday
# - 팔로워 수 : 174
#
#
# •Open am10:00-pm18:00
# •CS 네이버톡톡
# •스토어찜 2000원 할인쿠폰증정
# •전체상품을 클릭하시면 모든 상품을 볼 수 있습니다
#
#
# - 인스타그램 아이디 : lifelong_lab
# - 팔로워 수 : 1,476
#
#
#  #초상화에코백 #반려동물에코백
#
# @mosa_copy [대표님 드로잉에코백 계정]
#
#  #DM판매 #가성비
#  SET-UP & UNISEX & POINT BAG
#  언팔은언팔
#  피드속 제품 사이트에 없을 수 있습니다.
# (터)   (치)
#
#
# - 인스타그램 아이디 : red_chu25
# - 팔로워 수 : 172
#
#
#  현지 해외구매대행 업체
#  명품 ‘바잉’대행입니다 ️ ️
#  카카오톡으로 문의 주세요
#    구매대행 레드츄
#  더많은 제품정보 카톡   black9401
