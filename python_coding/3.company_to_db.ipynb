# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pymysql
import time
import datetime
import demoji
# 이모지 제거
# demoji.download_codes()
def loginUrl(user_id, user_pw):
    try:
        url = "https://www.instagram.com/"
        driver = webdriver.Chrome("./chromedriver.exe")
        driver.get(url)
        time.sleep(2)
        driver.find_element_by_name("username").send_keys(user_id)
        driver.find_element_by_name("password").send_keys(user_pw)
        time.sleep(2)
        driver.find_element_by_xpath("//*[@id=\"loginForm\"]/div/div[3]/button").submit()
        time.sleep(3)
#         driver.find_element_by_xpath("//*[@id=\"react-root\"]/section/main/div/div/div/div/button").click()
#         time.sleep(3)
        driver.find_element_by_xpath("/html/body/div[4]/div/div/div/div[3]/button[2]").click()
        insta_account(driver,company_list)
    except:
        print("잘못된 아이디 또는 비밀번호입니다.")

# %%
company_list=[]


f = open("C:/Users/정수/8%_project_python__int/회사계정/8percent_text_js.txt", 'r')
company_list = f.readlines()
f.close()

print(company_list)

def insta_account(driver,company_list):
    #이거 꼭 해줘야하는지 잘모르겠음
    url_tmp = driver.current_url
    
    for company in company_list:
        url = "https://www.instagram.com/{company}/".format(company=company)
        driver.get(url)#성공
        
        userIDList = driver.find_elements_by_css_selector("._7UhW9.fKFbl.yUEEX.KV-D4.fDxYl")
        userID = userIDList[0].text # 아이디

        userInfoList = driver.find_elements_by_css_selector(".g47SY")

        userPost = userInfoList[0] # 게시물 수
        userFollower = userInfoList[1] # 팔로워 수
        userFollowing = userInfoList[2] # 팔로잉 수

        userPostReal = userPost.get_attribute('title')
        userFollowerReal = userFollower.get_attribute('title')
        userFollowingReal = userFollowing.get_attribute('title')

        if userPost.text.find('백') == -1 and userPost.text.find('천') == -1 and userPost.text.find('만') == -1:
            userPost = userPost.text
        else:
            userPost = userPostReal
        if userFollower.text.find('백') == -1 and userFollower.text.find('천') == -1 and userFollower.text.find('만') == -1:
            userFollower = userFollower.text
        else:
            userFollower = userFollowerReal
        if userFollowing.text.find('백') == -1 and userFollowing.text.find('천') == -1 and userFollowing.text.find('만') == -1:
            userFollowing = userFollowing.text
        else:
            userFollowing = userFollowingReal
                
                
        print("- 인스타그램 아이디 : " + userID)
        print("- 팔로워 수 : " + userFollower)
            
        # 소개글
        intro = ""
        try:
            userInfoList = driver.find_elements_by_css_selector(".-vDIg span")
            intro = userInfoList[0].text
            intro = demoji.replace(intro," ")
            print(intro)
        except:
            continue
                
        dbData = [[url,userID,userPost,userFollower,userFollowing,intro]]
        connectDB1(dbData)
        
        insta_post_page(driver)
# Out:
# ['vtg_vivi\n', '_e_room_\n', 'so._eun\n', 'jeongmiyeong580\n', 'euncha_official\n', 'you_and_sara\n', 'yemm_ing\n', '_two_.guys_\n', 'happyinsta0013\n', '2cotoy\n', 'firstmoon__\n', 'k._.chacha\n', 'ul_93\n', 'noii_wholesale\n', 'm.made__\n', 'pieuna\n', 'ja___genn\n', 'danmi.in\n', 'juu.juu_o1\n', '2.5layer\n', 'onpoint_7\n', 'mixd_official\n', 'bbbr__\n', 'corolaflower\n', 'amado__cafe\n', '_tembox\n', 'modernday_h\n', 'mayth31_market\n', 'le_31mars\n', 'lindashop_daily\n', 'ciastory1122\n', 'lumeli._\n', 'geoje_twoandseven\n', 'kate_shop1209\n', 'flexgirl_official\n', 'bbnj_official\n', 'happyinsta0029\n', 'hangerisgood\n', 'shinwoo_st\n', 'nuunuu_home\n', 'hip_shop___\n', 'madeby.y_yang\n', 's_madeofficial\n', 'pptorning_\n', 'of_the9\n', 'incellderm00541\n', 'luv_riem\n', 'hwantastic_h2\n', 'mamre_studio\n', 'roum_jewelry\n', 'happyinsta0022\n', 's___00jj\n', 'yuk_min\n', 'sillysss_\n', 'cyanoki.kanazawa\n', 'bomnbom27\n', 'j_koo_foodie\n', 'diare_jewelry\n', '2be_andsome\n', 'tnwls__ps\n', 'bovelie_\n', 'made_loveday\n', 'el_bosque_official\n', 'udite_\n', 'su_ramisucloset\n', 'ari__seleb\n', 'gella_vintage\n', 'piano2339\n', 'mooong__chichi\n', 'otto_ne__\n', 'hunmin_onlooker\n', 'vely.b.yujin\n', 'my__yunee\n', 'cafe.miqreh\n', 'byaube\n', 'plating.studio\n', 'kyun.star\n', 'ellienne_cake\n', 'flower1nsta10\n', 'la.aile\n', 'nina_seoul\n', '_woo__ki___\n', 'ming4092\n', 'sunbay_yo\n', 'may_05___\n', 'stayeunyoung\n', 'benign99\n', 'munjeonbakdae\n', 'influmom\n', 'morethan0232\n', 'melimelo_case\n', 'lors_mood_daily\n', '_luis_ellie\n', 'noiidaiily\n', 'todaymelo\n', '2tilda_case\n', 'makemine__\n', 'callisohoney_store\n', 'ninedollar.co.kr\n', 'today.otto\n', 'vvely_99\n', 'ooa._.land\n', 'juilete_silver_\n', 'modebly_official\n', 'acaciabongbong\n', 'n_j.eun__s2\n', 'pellong_jennie\n', 'jme_market\n', 'je_spree\n', 'ryan_jomulzoo\n', 'making_701\n', 'hemming_ceramics\n', 'gaeon_baking\n', 'tory.pp_jewelry\n', 'sohyun55563\n', 'ethnicplum\n', 'sumi04100\n', 'luha__mom\n', 'vivicloset01\n', 'minkypress\n', 'yh00224\n', 'vintizip_official\n', 'ha_s_hoho\n', '_dain_o.o_\n', 'bebello__official\n', 'flowerinsta04\n', 'togetherwithyoun12\n', '0_topper\n', 'qween10986\n', 'jewelry.setter\n', '_dearsomething_\n', 'deliscent\n', 'joozaro\n', '1_pom____\n', 'paravion_nagoya\n', 'theotyouth\n', 'ang_star0302\n', 'somsom.nana_ha\n', 'vintagewook_gumi_shop2\n', 'elena_flowerlab\n', 'nam.taehyeon_\n', 'seryeong_ribbon\n', 'iroa____\n', 'suribyul\n', 'yu_baksa\n', 'bingha_net\n', 'chaedo_nayoung\n', 'inthenail615\n', 'zzzz_ram_e\n', 'hyeonjji\n', '_is.al\n', 'lovely_whitesnow\n', 'jyroom_m\n', 'ssong_label\n', 'ggomi_89\n', '__da.on__\n', 'guje_dunk\n', 'haleine_stay_md\n', 'byung_hyun_q\n', 'pb.club_2021\n', 'myouth_closet\n', 'yearstore_\n', 'fioco_official\n', 'b___o_h\n', 'gu9276\n', 'vely___jung\n', 'sodam__929\n', 'd_g__cookie\n', 'ian._.baking\n', 'gounlight\n', 'minidami_shoes\n', 'lst4545\n', 'norann_on\n', 'bitgoeul7\n', 'ilpoomdia\n', '0.0o___\n', 'cafe_oneul.haru\n', 't__a._.n__y\n', 'maman_aube\n', 'oggomee._.m\n', 'choi_yu_jin____\n', 'ink_your_life\n', 'raemontea\n', 'occo_acc\n', 'studio__january\n', 'aeborn_official\n', 'w_avelet\n', 'www_wish\n', 'phanie_daily\n', 'yellow_atelier0212\n', 'msg_company_joons\n', 'mienne_office\n', 'regne___official\n', 'mcrc3101\n', 'kkab__\n', '_______doyeonn\n', 'flowerinsta02\n', 'jiwooieo_o\n', 'kiji_kiji_\n', 'mantory__daily\n', 'better.elder\n', 'ra_mii\n', '_watch_ring_\n', 'rani._style\n', 'chaeon_\n', 'ndesign.r\n', 'sweet_sewing_village\n', 'iphone12pro.myapple\n', 'yeonipoint\n', 'lay_feel\n', 'mi_m_omimo\n', 'seungamarket\n', 'hn10183\n', 'rene_andyou\n', 'kang.vely0904\n', 'yujingram_99\n', 'labelle_yuri\n', 'bini_pw\n', 'bling_view\n', 'shop__suave\n', 'stocks.darim.app\n', 'gayeonene2\n', 'good_day_bake\n', '04.21.k\n', 'soo_a_37\n', 'sunny_shop712\n', 'gysllll\n', 'suda_bamboo\n', 'cutygirlfood\n', 'h_anchovy_\n', 'lavinia_handmade\n', 'chang.woon_\n', 'allluck_cafe\n ...

# %%
#한 회사의 게시글 목록 가져오는거..
def insta_post_page(driver):
    url = driver.current_url
    insta_post_Urs=[]
    
    # 게시글 url 리스트
    insta_post_Urs_List = []
    
#     #중복 제거한 url list
#     insta_post_Url_List=[]
    
    driver.get(url)
    time.sleep(2)
    
    
       # 스크롤 높이 가져옴
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
            
        insta_post_Urs= driver.find_elements_by_css_selector("._2z6nI .Nnq7C.weEfm .v1Nh3.kIKUG._bz0w a")
        for urlList in insta_post_Urs:
            insta_post_Urs_List.append(urlList.get_attribute("href"))
        
    # 끝까지 스크롤 다운
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # 1초 대기
        time.sleep(5)
        
    # 스크롤 다운 후 스크롤 높이 다시 가져옴
        new_height = driver.execute_script("return document.body.scrollHeight")
    
        #순서 섞이긴 하는데 상위 100개가 섞이는 것이다.
        #근데 딱 100개가 잘리는게아님... 3의 배수로 짤림 일단 그건 넘기고..
        insta_post_Url_List = list(set(insta_post_Urs_List))
        
        # 시험삼아 할때는 20개? 만 해보기=>그래도 맨날 24개나옴
        if len(insta_post_Url_List) >= 100:
            break
        
#         마지막부분
        if new_height == last_height:
            break

        last_height = new_height
        
    print(len(insta_post_Url_List))
    
    insta_post_Info(driver, insta_post_Url_List)

# %%
def insta_post_Info(driver,insta_post_Urs_List):
    for urlList in insta_post_Urs_List:
        driver.get(urlList)
        time.sleep(2)
        try:
            #계정이름
            userID=""
            userID_temp = driver.find_elements_by_css_selector(".sqdOP.yWX7d._8A5w5.ZIAjV")
            userID = userID_temp[0].text
            
            #위치정보 내용
            locations = ""
            locationsList = driver.find_elements_by_css_selector(".JF9hh")
            for location in locationsList:
                locations = locations + location.text
            #해시태그 내용
            tags = ""
            tagList = driver.find_elements_by_css_selector(".xil3i")
            for tag in tagList:
                tags = tags + tag.text
            #게시글 내용
            Contents = ""
            Content_List = driver.find_elements_by_css_selector(".eo2As .EtaWk .P9YgZ .C4VMK span")
            Content_temp = Content_List[1]
            Contents = Content_temp.text
            #이모티콘 지우는 코드. 위에 import demoji 이용.
            Contents = demoji.replace(Contents," ")
            
            
            # 게시글 날짜
            dates = ""
            dateList = driver.find_elements_by_css_selector("._1o9PC.Nzb55")
            for date in dateList:
                date = date.get_attribute('title')
                dates = dates + date
            #좋아요 수
            likes = ""

            try:
                like_List = driver.find_elements_by_css_selector(".Nm9Fw span")
                likes = like_List[0].text

            except:
                looklike_List = driver.find_element_by_xpath("//*[@id=\"react-root\"]/section/main/div/div[1]/article/div[3]/section[2]/div/span").click()
                
                looklike_temp = driver.find_elements_by_css_selector(".vJRqr span")
                likes = looklike_temp[0].text
            
            print("- url - ")
            print(urlList)
            
            print("- 계정이름 - ")
            print(userID)
            print("\n- 위치 정보 - ")
            print(locations)
            print("\n- 해시태그 - ")
            print(tags)
            print("\n- 게시글 본문 - ")
            print(Contents)
            print("\n- 작성날짜 - ")
            print(dates)
            print("\n- 좋아요수 - ")
            print(likes)

            dbData2 = [[urlList,userID,locations,tags,Contents,dates,likes]]
            connectDB2(dbData2)


        except:
            continue

# %%
#company_profile

def connectDB1(dbData):

    DB_HOST = '127.0.0.1'
    DB_USER = 'root'
    DB_PASSWD = 'autoset'
    #각자 데이터베이스의 이름
    DB_NAME = '8percent'
    
    conn = pymysql.connect(host=DB_HOST, user=DB_USER, password=DB_PASSWD,
                       db=DB_NAME, charset='utf8')
    
    curs = conn.cursor()
    #테이블이름
    sql = """insert into company_profile(url,id,postnum,followernum,followingnum,intro) values (%s, %s, %s, %s, %s, %s)"""

    curs.executemany(sql, dbData)
    
    conn.commit()

    conn.close()
    
    
def connectDB2(dbData2):

    DB_HOST = '127.0.0.1'
    DB_USER = 'root'
    DB_PASSWD = 'autoset'
    #각자 데이터베이스의 이름
    DB_NAME = '8percent'
    
    conn = pymysql.connect(host=DB_HOST, user=DB_USER, password=DB_PASSWD,
                       db=DB_NAME, charset='utf8')
    
    curs = conn.cursor()
    #테이블이름
    sql2 = """insert into company_post(url,id,location,tags,contents,date,likes) values (%s, %s, %s, %s, %s, %s, %s)"""

    curs.executemany(sql2, dbData2)
    
    conn.commit()

    conn.close()

# %%
#SQL


#프라이머리키 no일까 id일까? id도 중복 안될텐데..

# CREATE TABLE `company_profile`(
#     `no` INT(20) NOT NULL AUTO_INCREMENT,
#     `url` VARCHAR(100) NULL DEFAULT NULL,
#     `id` VARCHAR(100) NULL DEFAULT NULL,
#     `postnum` VARCHAR(100) NULL DEFAULT NULL,
#     `followernum` VARCHAR(100) NULL DEFAULT NULL,
#     `followingnum` VARCHAR(100) NULL DEFAULT NULL,
#     `intro` VARCHAR(100) NULL DEFAULT NULL,
#     PRIMARY KEY(`no`)
#     )DEFAULT CHARSET=utf8;



# 이건 프라이머리키 no맞는듯
#변수 이름 like->likes
# CREATE TABLE `company_post`(
#     `no` INT(20) NOT NULL AUTO_INCREMENT,
#     `url` VARCHAR(1000) NULL DEFAULT NULL,
#     `id` VARCHAR(100) NULL DEFAULT NULL,
#     `location` VARCHAR(100) NULL DEFAULT NULL,
#     `tags` VARCHAR(1000) NULL DEFAULT NULL,
#     `contents` VARCHAR(10000) NULL DEFAULT NULL,
#     `date` VARCHAR(100) NULL DEFAULT NULL,
#     `likes` VARCHAR(100) NULL DEFAULT NULL,
#     PRIMARY KEY(`no`)
#     )DEFAULT CHARSET=utf8;

# %%
user_id = "jjungsu_drawing"
user_pw = "jsjs532525!!"
loginUrl(user_id, user_pw)
# Out:
# - 인스타그램 아이디 : vtg_vivi
# - 팔로워 수 : 5,317
#  빈티지샵 빈티지 비비 입니다
#  택배 배송비 일반지역3천원 / 제주 및 산간지역 7천원
#  문의는 디엠으로 받고 답장없을때 아래 오픈챗 이용바래요
#  5만원 이상 구매시 배송비 무료
# 24
# - url -
# https://www.instagram.com/p/CLRUKv_nRnB/
# - 계정이름 -
# vtg_vivi
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #빈티지비비구매가능#빈티지샵#구제#구제샵#빈티지#구제쇼핑몰#구제옷#올드스쿨#미니멀룩#오늘의코디#남녀공용#맨투맨#맨투맨추천#봄맞이신상
#
# - 게시글 본문 -
#   나이키 사파리 자켓 #빈티지비비구매가능
# -
#  사이즈 : L 가슴 : 60 총장 : 76
# -
#  상태 : 9
# -
#  가격 : 2.5
# -
#  문의는 DM 디엠으로만 받습니다
# -
#  사진에 오염이 보이는것은 그것을 감안하고 가격을 맞춘것입다 그래서 추가적인 할인은 없습니다
# -
#  모든 사이즈는 실측을 기준으로 하였습니다
#
# - 작성날짜 -
# 2021년 2월 14일
#
# - 좋아요수 -
# 2
# - url -
# https://www.instagram.com/p/CLRQFX-nbZ9/
# - 계정이름 -
# vtg_vivi
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #빈티지비비구매가능#빈티지샵#구제#구제샵#빈티지#구제쇼핑몰#구제옷#올드스쿨#미니멀룩#오늘의코디#남녀공용#맨투맨#맨투맨추천#봄맞이신상
#
# - 게시글 본문 -
#   폴로 자켓(면) #빈티지비비구매가능
# -
#  사이즈 : XL 가슴 : 64 총장 : 72
# -
#  상태 : 9
# -
#  가격 : 2.5
# -
#  문의는 DM 디엠으로만 받습니다
# -
#  사진에 오염이 보이는것은 그것을 감안하고 가격을 맞춘것입다 그래서 추가적인 할인은 없습니다
# -
#  모든 사이즈는 실측을 기준으로 하였습니다
#
# - 작성날짜 -
# 2021년 2월 14일
#
# - 좋아요수 -
# 2
# - url -
# https://www.instagram.com/p/CLRSHgWHZme/
# - 계정이름 -
# vtg_vivi
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #빈티지샵#구제#구제샵#빈티지#구제쇼핑몰#구제옷#올드스쿨#미니멀룩#오늘의코디#남녀공용#맨투맨#맨투맨추천#봄맞이신상
#
# - 게시글 본문 -
#
#
# - 작성날짜 -
# 2021년 2월 14일
#
# - 좋아요수 -
# 2
# - url -
# https://www.instagram.com/p/CLRPK5KHjmm/
# - 계정이름 -
# vtg_vivi
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #빈티지비비구매가능#빈티지샵#구제#구제샵#빈티지#구제쇼핑몰#구제옷#올드스쿨#미니멀룩#오늘의코디#남녀공용#맨투맨#맨투맨추천#봄맞이신상
#
# - 게시글 본문 -
#   폴로 와플 맨투맨 #빈티지비비구매가능
# -
#  사이즈 : M 가슴 : 58 총장 : 78
# -
#  상태 : 9
# -
#  가격 : 2
# -
#  문의는 DM 디엠으로만 받습니다
# -
#  사진에 오염이 보이는것은 그것을 감안하고 가격을 맞춘것입다 그래서 추가적인 할인은 없습니다
# -
#  모든 사이즈는 실측을 기준으로 하였습니다
#
# - 작성날짜 -
# 2021년 2월 14일
#
# - 좋아요수 -
# 3
# - url -
# https://www.instagram.com/p/CLRSNm_n1uj/
# - 계정이름 -
# vtg_vivi
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #빈티지비비구매가능#빈티지샵#구제#구제샵#빈티지#구제쇼핑몰#구제옷#올드스쿨#미니멀룩#오늘의코디#남녀공용#맨투맨#맨투맨추천#봄맞이신상
#
# - 게시글 본문 -
#   나이키 바람막이 #빈티지비비구매가능
# -
#  사이즈 : L 가슴 : 64 총장 : 72
# -
#  상태 : 9
# -
#  가격 : 2.0
# -
#  문의는 DM 디엠으로만 받습니다
# -
#  사진에 오염이 보이는것은 그것을 감안하고 가격을 맞춘것입다 그래서 추가적인 할인은 없습니다
# -
#  모든 사이즈는 실측을 기준으로 하였습니다
#
# - 작성날짜 -
# 2021년 2월 14일
#
# - 좋아요수 -
# 5
# - url -
# https://www.instagram.com/p/CLRUbYEna5H/
# - 계정이름 -
# vtg_vivi
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #빈티지비비구매가능#빈티지샵#구제#구제샵#빈티지#구제쇼핑몰#구제옷#올드스쿨#미니멀룩#오늘의코디#남녀공용#맨투맨#맨투맨추천#봄맞이신상
#
# - 게시글 본문 -
#   나이키 스우시 나일론 트랙자켓 #빈티지비비구매가능
# -
#  사이즈 : XL 가슴 : 64 총장 : 76
# -
#  상태 : 9(다크네이비)
# -
#  가격 : 3
# -
#  문의는 DM 디엠으로만 받습니다
# -
#  사진에 오염이 보이는것은 그것을 감안하고 가격을 맞춘것입다 그래서 추가적인 할인은 없습니다
# -
#  모든 사이즈는 실측을 기준으로 하였습니다
#
# - 작성날짜 -
# 2021년 2월 14일
#
# - 좋아요수 -
# 5
# - url -
# https://www.instagram.com/p/CLRO9PRHX0F/
# - 계정이름 -
# vtg_vivi
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #빈티지비비구매가능#빈티지샵#구제#구제샵#빈티지#구제쇼핑몰#구제옷#올드스쿨#미니멀룩#오늘의코디#남녀공용#맨투맨#맨투맨추천#봄맞이신상
#
# - 게시글 본문 -
#   아디다스 후드티 #빈티지비비구매가능
# -
#  사이즈 : M 가슴 : 58 총장 : 60
# -
#  상태 : 8.5
# -
#  가격 : 1.7
# -
#  문의는 DM 디엠으로만 받습니다
# -
#  사진에 오염이 보이는것은 그것을 감안하고 가격을 맞춘것입다 그래서 추가적인 할인은 없습니다
# -
#  모든 사이즈는 실측을 기준으로 하였습니다
#
# - 작성날짜 -
# 2021년 2월 14일
#
# - 좋아요수 -
# 2
# - url -
# https://www.instagram.com/p/CLTu2vPHK6z/
# - 계정이름 -
# vtg_vivi
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #빈티지샵#구제#구제샵#빈티지#구제쇼핑몰#구제옷#올드스쿨#미니멀룩#오늘의코디#남녀공용#맨투맨#맨투맨추천#봄맞이신상
#
# - 게시글 본문 -
# #빈티지샵 #구제 #구제샵 #빈티지 #구제쇼핑몰 #구제옷 #올드스쿨 #미니멀룩 #오늘의코디 #남녀공용 #맨투맨 #맨투맨추천 #봄맞이신상
#
# - 작성날짜 -
# 2021년 2월 15일
#
# - 좋아요수 -
# 18
# - url -
# https://www.instagram.com/p/CLRShaWn7Ub/
# - 계정이름 -
# vtg_vivi
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #빈티지비비구매가능#빈티지샵#구제#구제샵#빈티지#구제쇼핑몰#구제옷#올드스쿨#미니멀룩#오늘의코디#남녀공용#맨투맨#맨투맨추천#봄맞이신상
#
# - 게시글 본문 -
#   휠라 웜업 #빈티지비비구매가능
# -
#  사이즈 : XL 가슴 : 66 총장 : 75
# -
#  상태 : 9
# -
#  가격 : 2.5
# -
#  문의는 DM 디엠으로만 받습니다
# -
#  사진에 오염이 보이는것은 그것을 감안하고 가격을 맞춘것입다 그래서 추가적인 할인은 없습니다
# -
#  모든 사이즈는 실측을 기준으로 하였습니다
#
# - 작성날짜 -
# 2021년 2월 14일
#
# - 좋아요수 -
# 3
# - url -
# https://www.instagram.com/p/CLRSDJlHgLB/
# - 계정이름 -
# vtg_vivi
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #빈티지비비구매가능#빈티지샵#구제#구제샵#빈티지#구제쇼핑몰#구제옷#올드스쿨#미니멀룩#오늘의코디#남녀공용#맨투맨#맨투맨추천#봄맞이신상
#
# - 게시글 본문 -
#   나이키 저지 #빈티지비비구매가능
# -
#  사이즈 : L 가슴 : 60 총장 : 72
# -
#  상태 : 9
# -
#  가격 : 2.0
# -
#  문의는 DM 디엠으로만 받습니다
# -
#  사진에 오염이 보이는것은 그것을 감안하고 가격을 맞춘것입다 그래서 추가적인 할인은 없습니다
# -
#  모든 사이즈는 실측을 기준으로 하였습니다
#
# - 작성날짜 -
# 2021년 2월 14일
#
# - 좋아요수 -
# 4
# - url -
# https://www.instagram.com/p/CLRQK8rHmjt/
# - 계정이름 -
# vtg_vivi
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #빈티지비비구매가능#빈티지샵#구제#구제샵#빈티지#구제쇼핑몰#구제옷#올드스쿨#미니멀룩#오늘의코디#남녀공용#맨투맨#맨투맨추천#봄맞이신상
#
# - 게시글 본문 -
#   라코스테 가디건 #빈티지비비구매가능
# -
#  사이즈 : L 가슴 : 62 총장 : 68
# -
#  상태 : 8.5
# -
#  가격 : 2.2
# -
#  문의는 DM 디엠으로만 받습니다
# -
#  사진에 오염이 보이는것은 그것을 감안하고 가격을 맞춘것입다 그래서 추가적인 할인은 없습니다
# -
#  모든 사이즈는 실측을 기준으로 하였습니다
#
# - 작성날짜 -
# 2021년 2월 14일
#
# - 좋아요수 -
# 5
# - url -
# https://www.instagram.com/p/CLRT55PHJai/
# - 계정이름 -
# vtg_vivi
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #빈티지샵#구제#구제샵#빈티지#구제쇼핑몰#구제옷#올드스쿨#미니멀룩#오늘의코디#남녀공용#맨투맨#맨투맨추천#봄맞이신상
#
# - 게시글 본문 -
#
#
# - 작성날짜 -
# 2021년 2월 14일
#
# - 좋아요수 -
# 2
# - url -
# https://www.instagram.com/p/CLRQiYAH01v/
# - 계정이름 -
# vtg_vivi
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #빈티지비비구매가능#빈티지샵#구제#구제샵#빈티지#구제쇼핑몰#구제옷#올드스쿨#미니멀룩#오늘의코디#남녀공용#맨투맨#맨투맨추천#봄맞이신상
#
# - 게시글 본문 -
#   폴로 숄카라 니트 #빈티지비비구매가능
# -
#  사이즈 : L 가슴 : 60 총장 : 68
# -
#  상태 : 8.5
# -
#  가격 : 2.0
# -
#  문의는 DM 디엠으로만 받습니다
# -
#  사진에 오염이 보이는것은 그것을 감안하고 가격을 맞춘것입다 그래서 추가적인 할인은 없습니다
# -
#  모든 사이즈는 실측을 기준으로 하였습니다
#
# - 작성날짜 -
# 2021년 2월 14일
#
# - 좋아요수 -
# 2
# - url -
# https://www.instagram.com/p/CLRQvyBnCCn/
# - 계정이름 -
# vtg_vivi
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #빈티지비비구매가능#빈티지샵#구제#구제샵#빈티지#구제쇼핑몰#구제옷#올드스쿨#미니멀룩#오늘의코디#남녀공용#맨투맨#맨투맨추천#봄맞이신상
#
# - 게시글 본문 -
#   나이키 후드집업 #빈티지비비구매가능
# -
#  사이즈 : L 가슴 : 62 총장 : 66
# -
#  상태 : 9
# -
#  가격 : 2.0
# -
#  문의는 DM 디엠으로만 받습니다
# -
#  사진에 오염이 보이는것은 그것을 감안하고 가격을 맞춘것입다 그래서 추가적인 할인은 없습니다
# -
#  모든 사이즈는 실측을 기준으로 하였습니다
#
# - 작성날짜 -
# 2021년 2월 14일
#
# - 좋아요수 -
# 4
# - url -
# https://www.instagram.com/p/CLRRy0aH11a/
# - 계정이름 -
# vtg_vivi
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #빈티지샵#구제#구제샵#빈티지#구제쇼핑몰#구제옷#올드스쿨#미니멀룩#오늘의코디#남녀공용#맨투맨#맨투맨추천#봄맞이신상
#
# - 게시글 본문 -
#
#
# - 작성날짜 -
# 2021년 2월 14일
#
# - 좋아요수 -
# 2
# - 인스타그램 아이디 : _e_room_
# - 팔로워 수 : 573
# 안동 옷가게 ᰔᩚ
# 안동시 경동로 515 / 안동중 건너편
# 24
# - url -
# https://www.instagram.com/p/CK1EgSGDlVA/
# - 계정이름 -
# _e_room_
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #레고좋아함
#
# - 게시글 본문 -
# 규범이가 낮에 계속 자기가방을 내놓으라고 무슨가방이란 가방 다꺼내서 줘도 다아니라고..가방을 그렇게 찾더니 혼자서 조용히 놀길래 보니까 저 레고가방을 손에 쥐고는 자기가방이래^^이테까지 찾던 가방이 그 가방이냐고....잃어버리지마라..진짜..
# #레고좋아함
# 레고에 있는 손톱보다 작은 소품들 좋아함ㅠㅠ
# 잃어버리면 찾는데 몇일....
#
# - 작성날짜 -
# 2021년 2월 3일
#
# - 좋아요수 -
# 31
# - url -
# https://www.instagram.com/p/CK3TLWRjpEY/
# - 계정이름 -
# _e_room_
#
# - 위치 정보 -
#
#
# - 해시태그 -
# #안동옷집#안동이룸#봄신상#가디건#예비맘#77사이즈#편한옷#청바지#안동#경북도청#택배가능#데일리#데일리룩#꾸안꾸#봄#등원룩#오오디티#맨투맨#원피스#출근룩#육아#좋아요
#
# - 게시글 본문 -
# 귀여운 스누피
#
# #안동옷집#안동이룸
# #봄신상#가디건#예비맘#77사이즈#편한옷#청바지#안동#경북도청#택배가능#데일리#데일리룩#꾸안꾸#봄#등원룩#오오디티#맨투맨#원피스#출근룩#육아#좋아요
#
# - 작성날짜 -
# 2021년 2월 4일
#
# - 좋아요수 -
# 16
# 잘못된 아이디 또는 비밀번호입니다.
